# %%
from catmap import ReactionModel

mkm_file = 'fr cracking.mkm'
model = ReactionModel(setup_file=mkm_file)
model.output_variables += ['production_rate','rate','rate_control','coverage','selectivity_control','rxn_order']
model.run()

from catmap import analyze
vm = analyze.VectorMap(model)
vm.plot_variable = 'rate' #tell the model which output to plot
vm.log_scale = True #rates should be plotted on a log-scale
vm.min = 1e-25 #minimum rate to plot
vm.max = 1e3 #maximum rate to plot
vm.plot(save='rate.pdf') #draw the plot and save it as "rate.pdf"

vm.unique_only = False
vm.plot(save='all_rates.pdf')
vm.unique_only = True

vm.production_rate_map = model.production_rate_map #attach map
vm.threshold = 1e-30 #do not plot rates below this
vm.plot_variable = 'production_rate'
vm.plot(save='production_rate.pdf')

vm.descriptor_labels = ['H adsorption [eV]', 'O adsorption [eV]']
vm.subplots_adjust_kwargs = {'left':0.2,'right':0.8,'bottom':0.15}
vm.plot(save='pretty_production_rate.pdf')

vm.plot_variable = 'coverage'
vm.log_scale = False
vm.min = 0
vm.max = 1
vm.plot(save='coverage.pdf')

vm.include_labels = ['C5H9OH_s']
vm.plot(save='C5H9OH_coverage.pdf')

sa = analyze.ScalingAnalysis(model)
sa.plot(save='scaling.pdf')
# Out:
# mapper_iteration_0: status - 144 points do not have valid solution.
# minresid_iteration_0: success - [ 2.00, 1.00] using coverages from [ 2.00, 1.00]
# minresid_iteration_0: success - [ 2.00, 0.64] using coverages from [ 2.00, 0.64]
# minresid_iteration_0: success - [ 2.00, 0.27] using coverages from [ 2.00, 0.27]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 4.62157941222745e+17)
# minresid_iteration_0: fail - [ 2.00,-0.09] using coverages from [ 2.00,-0.09]; initial residual was 1.205264850986843e+39 (residual = 4.62157941222745e+17)
# minresid_iteration_1: success - [ 2.00,-0.09] using coverages from [ 2.00, 0.27]
# minresid_iteration_0: success - [ 2.00,-0.45] using coverages from [ 2.00,-0.45]
# minresid_iteration_0: success - [ 2.00,-0.82] using coverages from [ 2.00,-0.82]
# minresid_iteration_0: success - [ 2.00,-1.18] using coverages from [ 2.00,-1.18]
# minresid_iteration_0: success - [ 2.00,-1.55] using coverages from [ 2.00,-1.55]
# minresid_iteration_0: success - [ 2.00,-1.91] using coverages from [ 2.00,-1.91]
# minresid_iteration_0: success - [ 2.00,-2.27] using coverages from [ 2.00,-2.27]
# minresid_iteration_0: success - [ 2.00,-2.64] using coverages from [ 2.00,-2.64]
# minresid_iteration_0: success - [ 2.00,-3.00] using coverages from [ 2.00,-3.00]
# minresid_iteration_0: success - [ 1.73, 1.00] using coverages from [ 1.73, 1.00]
# minresid_iteration_0: success - [ 1.73, 0.64] using coverages from [ 1.73, 0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.3007097294117025e+18)
# minresid_iteration_0: fail - [ 1.73, 0.27] using coverages from [ 1.73, 0.27]; initial residual was 1.3574350322678469e+39 (residual = 1.3007097294117025e+18)
# minresid_iteration_1: success - [ 1.73, 0.27] using coverages from [ 1.73, 0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 4.4983113918939433e+18)
# minresid_iteration_0: fail - [ 1.73,-0.09] using coverages from [ 1.73,-0.09]; initial residual was 1.8295048607398134e+40 (residual = 4.4983113918939433e+18)
# minresid_iteration_1: success - [ 1.73,-0.09] using coverages from [ 1.73, 0.27]
# minresid_iteration_0: success - [ 1.73,-0.45] using coverages from [ 1.73,-0.45]
# minresid_iteration_0: success - [ 1.73,-0.82] using coverages from [ 1.73,-0.82]
# minresid_iteration_0: success - [ 1.73,-1.18] using coverages from [ 1.73,-1.18]
# minresid_iteration_0: success - [ 1.73,-1.55] using coverages from [ 1.73,-1.55]
# minresid_iteration_0: success - [ 1.73,-1.91] using coverages from [ 1.73,-1.91]
# minresid_iteration_0: success - [ 1.73,-2.27] using coverages from [ 1.73,-2.27]
# minresid_iteration_0: success - [ 1.73,-2.64] using coverages from [ 1.73,-2.64]
# minresid_iteration_0: success - [ 1.73,-3.00] using coverages from [ 1.73,-3.00]
# minresid_iteration_0: success - [ 1.45, 1.00] using coverages from [ 1.45, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.0478634959659057e+18)
# minresid_iteration_0: fail - [ 1.45, 0.64] using coverages from [ 1.45, 0.64]; initial residual was 1.528817356025071e+39 (residual = 1.0478634959659057e+18)
# minresid_iteration_1: success - [ 1.45, 0.64] using coverages from [ 1.45, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 3.053153394945334e+19)
# minresid_iteration_0: fail - [ 1.45, 0.27] using coverages from [ 1.45, 0.27]; initial residual was 2.06048794491465e+40 (residual = 3.053153394945334e+19)
# minresid_iteration_1: success - [ 1.45, 0.27] using coverages from [ 1.45, 0.64]
# minresid_iteration_0: success - [ 1.45,-0.09] using coverages from [ 1.45,-0.09]
# minresid_iteration_0: success - [ 1.45,-0.45] using coverages from [ 1.45,-0.45]
# minresid_iteration_0: success - [ 1.45,-0.82] using coverages from [ 1.45,-0.82]
# minresid_iteration_0: success - [ 1.45,-1.18] using coverages from [ 1.45,-1.18]
# minresid_iteration_0: success - [ 1.45,-1.55] using coverages from [ 1.45,-1.55]
# minresid_iteration_0: success - [ 1.45,-1.91] using coverages from [ 1.45,-1.91]
# minresid_iteration_0: success - [ 1.45,-2.27] using coverages from [ 1.45,-2.27]
# minresid_iteration_0: success - [ 1.45,-2.64] using coverages from [ 1.45,-2.64]
# minresid_iteration_0: success - [ 1.45,-3.00] using coverages from [ 1.45,-3.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 8.11502711553871e+17)
# minresid_iteration_0: fail - [ 1.18, 1.00] using coverages from [ 1.18, 1.00]; initial residual was 1.721837102911105e+39 (residual = 8.11502711553871e+17)
# minresid_iteration_1: success - [ 1.18, 1.00] using coverages from [ 1.45, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 7.563498621487914e+18)
# minresid_iteration_0: fail - [ 1.18, 0.64] using coverages from [ 1.18, 0.64]; initial residual was 2.320633701084943e+40 (residual = 7.563498621487914e+18)
# minresid_iteration_1: success - [ 1.18, 0.64] using coverages from [ 1.18, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 4.154820102480178e+19)
# minresid_iteration_0: fail - [ 1.18, 0.27] using coverages from [ 1.18, 0.27]; initial residual was 3.128141341098116e+41 (residual = 4.154820102480178e+19)
# minresid_iteration_1: success - [ 1.18, 0.27] using coverages from [ 1.18, 0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.9831238374801514e+19)
# minresid_iteration_0: fail - [ 1.18,-0.09] using coverages from [ 1.18,-0.09]; initial residual was 4.216636127743576e+42 (residual = 1.9831238374801514e+19)
# minresid_iteration_1: success - [ 1.18,-0.09] using coverages from [ 1.18, 0.27]
# minresid_iteration_0: success - [ 1.18,-0.45] using coverages from [ 1.18,-0.45]
# minresid_iteration_0: success - [ 1.18,-0.82] using coverages from [ 1.18,-0.82]
# minresid_iteration_0: success - [ 1.18,-1.18] using coverages from [ 1.18,-1.18]
# minresid_iteration_0: success - [ 1.18,-1.55] using coverages from [ 1.18,-1.55]
# minresid_iteration_0: success - [ 1.18,-1.91] using coverages from [ 1.18,-1.91]
# minresid_iteration_0: success - [ 1.18,-2.27] using coverages from [ 1.18,-2.27]
# minresid_iteration_0: success - [ 1.18,-2.64] using coverages from [ 1.18,-2.64]
# minresid_iteration_0: success - [ 1.18,-3.00] using coverages from [ 1.18,-3.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 7.968027058498728e+17)
# minresid_iteration_0: fail - [ 0.91, 1.00] using coverages from [ 0.91, 1.00]; initial residual was 2.6140165004599756e+40 (residual = 7.968027058498728e+17)
# minresid_iteration_1: success - [ 0.91, 1.00] using coverages from [ 1.18, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 5.35612620778492e+18)
# minresid_iteration_0: fail - [ 0.91, 0.64] using coverages from [ 0.91, 0.64]; initial residual was 3.5230832784979896e+41 (residual = 5.35612620778492e+18)
# minresid_iteration_1: success - [ 0.91, 0.64] using coverages from [ 0.91, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 2.7256378467400745e+19)
# minresid_iteration_0: fail - [ 0.91, 0.27] using coverages from [ 0.91, 0.27]; initial residual was 4.7490054423583973e+42 (residual = 2.7256378467400745e+19)
# minresid_iteration_1: success - [ 0.91, 0.27] using coverages from [ 0.91, 0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.6620859214472547e+17)
# minresid_iteration_0: fail - [ 0.91,-0.09] using coverages from [ 0.91,-0.09]; initial residual was 3.721314180358278e+41 (residual = 1.6620859214472547e+17)
# minresid_iteration_1: success - [ 0.91,-0.09] using coverages from [ 0.91, 0.27]
# minresid_iteration_0: success - [ 0.91,-0.45] using coverages from [ 0.91,-0.45]
# minresid_iteration_0: success - [ 0.91,-0.82] using coverages from [ 0.91,-0.82]
# minresid_iteration_0: success - [ 0.91,-1.18] using coverages from [ 0.91,-1.18]
# minresid_iteration_0: success - [ 0.91,-1.55] using coverages from [ 0.91,-1.55]
# minresid_iteration_0: success - [ 0.91,-1.91] using coverages from [ 0.91,-1.91]
# minresid_iteration_0: success - [ 0.91,-2.27] using coverages from [ 0.91,-2.27]
# minresid_iteration_0: success - [ 0.91,-2.64] using coverages from [ 0.91,-2.64]
# minresid_iteration_0: success - [ 0.91,-3.00] using coverages from [ 0.91,-3.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 4.2677958290419296e+17)
# minresid_iteration_0: fail - [ 0.64, 1.00] using coverages from [ 0.64, 1.00]; initial residual was 3.9678884219916414e+41 (residual = 4.2677958290419296e+17)
# minresid_iteration_1: success - [ 0.64, 1.00] using coverages from [ 0.91, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 2.2479764877211666e+18)
# minresid_iteration_0: fail - [ 0.64, 0.64] using coverages from [ 0.64, 0.64]; initial residual was 4.4538299712076867e+42 (residual = 2.2479764877211666e+18)
# minresid_iteration_1: success - [ 0.64, 0.64] using coverages from [ 0.64, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 7.017256478609336e+16)
# minresid_iteration_0: fail - [ 0.64, 0.27] using coverages from [ 0.64, 0.27]; initial residual was 3.304060114826474e+41 (residual = 7.017256478609336e+16)
# minresid_iteration_1: success - [ 0.64, 0.27] using coverages from [ 0.64, 0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 807339221472701.6)
# minresid_iteration_0: fail - [ 0.64,-0.09] using coverages from [ 0.64,-0.09]; initial residual was 2.4514746021640603e+40 (residual = 807339221472701.6)
# minresid_iteration_1: success - [ 0.64,-0.09] using coverages from [ 0.64, 0.27]
# minresid_iteration_0: success - [ 0.64,-0.45] using coverages from [ 0.64,-0.45]
# minresid_iteration_0: success - [ 0.64,-0.82] using coverages from [ 0.64,-0.82]
# minresid_iteration_0: success - [ 0.64,-1.18] using coverages from [ 0.64,-1.18]
# minresid_iteration_0: success - [ 0.64,-1.55] using coverages from [ 0.64,-1.55]
# minresid_iteration_0: success - [ 0.64,-1.91] using coverages from [ 0.64,-1.91]
# minresid_iteration_0: success - [ 0.64,-2.27] using coverages from [ 0.64,-2.27]
# minresid_iteration_0: success - [ 0.64,-2.64] using coverages from [ 0.64,-2.64]
# minresid_iteration_0: success - [ 0.64,-3.00] using coverages from [ 0.64,-3.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.3937605285258163e+17)
# minresid_iteration_0: fail - [ 0.36, 1.00] using coverages from [ 0.36, 1.00]; initial residual was 3.9544422451268653e+42 (residual = 1.3937605285258163e+17)
# minresid_iteration_1: success - [ 0.36, 1.00] using coverages from [ 0.64, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 4841051370946750.0)
# minresid_iteration_0: fail - [ 0.36, 0.64] using coverages from [ 0.36, 0.64]; initial residual was 2.9335908532786436e+41 (residual = 4841051370946750.0)
# minresid_iteration_1: success - [ 0.36, 0.64] using coverages from [ 0.36, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 160054878270115.8)
# minresid_iteration_0: fail - [ 0.36, 0.27] using coverages from [ 0.36, 0.27]; initial residual was 2.1766018639703866e+40 (residual = 160054878270115.8)
# minresid_iteration_1: success - [ 0.36, 0.27] using coverages from [ 0.36, 0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 3004969376563.3267)
# minresid_iteration_0: fail - [ 0.36,-0.09] using coverages from [ 0.36,-0.09]; initial residual was 1.614704555643118e+39 (residual = 3004969376563.3267)
# minresid_iteration_1: success - [ 0.36,-0.09] using coverages from [ 0.36, 0.27]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 4913253320.618582)
# minresid_iteration_0: fail - [ 0.36,-0.45] using coverages from [ 0.36,-0.45]; initial residual was 1.198040918097066e+38 (residual = 4913253320.618582)
# minresid_iteration_1: success - [ 0.36,-0.45] using coverages from [ 0.36,-0.09]
# minresid_iteration_0: success - [ 0.36,-0.82] using coverages from [ 0.36,-0.82]
# minresid_iteration_0: success - [ 0.36,-1.18] using coverages from [ 0.36,-1.18]
# minresid_iteration_0: success - [ 0.36,-1.55] using coverages from [ 0.36,-1.55]
# minresid_iteration_0: success - [ 0.36,-1.91] using coverages from [ 0.36,-1.91]
# minresid_iteration_0: success - [ 0.36,-2.27] using coverages from [ 0.36,-2.27]
# minresid_iteration_0: success - [ 0.36,-2.64] using coverages from [ 0.36,-2.64]
# minresid_iteration_0: success - [ 0.36,-3.00] using coverages from [ 0.36,-3.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 298612845076147.1)
# minresid_iteration_0: fail - [ 0.09, 1.00] using coverages from [ 0.09, 1.00]; initial residual was 2.604660627884231e+41 (residual = 298612845076147.1)
# minresid_iteration_1: success - [ 0.09, 1.00] using coverages from [ 0.36, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 10403670090462.666)
# minresid_iteration_0: fail - [ 0.09, 0.64] using coverages from [ 0.09, 0.64]; initial residual was 1.9325493590070502e+40 (residual = 10403670090462.666)
# minresid_iteration_1: success - [ 0.09, 0.64] using coverages from [ 0.09, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 353444538523.8313)
# minresid_iteration_0: fail - [ 0.09, 0.27] using coverages from [ 0.09, 0.27]; initial residual was 1.4338702414940065e+39 (residual = 353444538523.8313)
# minresid_iteration_1: success - [ 0.09, 0.27] using coverages from [ 0.09, 0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 8926968810.255413)
# minresid_iteration_0: fail - [ 0.09,-0.09] using coverages from [ 0.09,-0.09]; initial residual was 1.0637098835705259e+38 (residual = 8926968810.255413)
# minresid_iteration_1: success - [ 0.09,-0.09] using coverages from [ 0.09, 0.27]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 33967749.263666235)
# minresid_iteration_0: fail - [ 0.09,-0.45] using coverages from [ 0.09,-0.45]; initial residual was 7.892212250965114e+36 (residual = 33967749.263666235)
# minresid_iteration_1: success - [ 0.09,-0.45] using coverages from [ 0.09,-0.09]
# minresid_iteration_0: success - [ 0.09,-0.82] using coverages from [ 0.09,-0.82]
# minresid_iteration_0: success - [ 0.09,-1.18] using coverages from [ 0.09,-1.18]
# minresid_iteration_0: success - [ 0.09,-1.55] using coverages from [ 0.09,-1.55]
# minresid_iteration_0: success - [ 0.09,-1.91] using coverages from [ 0.09,-1.91]
# minresid_iteration_0: success - [ 0.09,-2.27] using coverages from [ 0.09,-2.27]
# minresid_iteration_0: success - [ 0.09,-2.64] using coverages from [ 0.09,-2.64]
# minresid_iteration_0: success - [ 0.09,-3.00] using coverages from [ 0.09,-3.00]
# minresid_iteration_0: success - [-0.18, 1.00] using coverages from [-0.18, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 22307053654.502567)
# minresid_iteration_0: fail - [-0.18, 0.64] using coverages from [-0.18, 0.64]; initial residual was 1.2730968198790993e+39 (residual = 22307053654.502567)
# minresid_iteration_1: success - [-0.18, 0.64] using coverages from [-0.18, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 768240213.1626097)
# minresid_iteration_0: fail - [-0.18, 0.27] using coverages from [-0.18, 0.27]; initial residual was 9.44440760380105e+37 (residual = 768240213.1626097)
# minresid_iteration_1: success - [-0.18, 0.27] using coverages from [-0.18, 0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 22813467.35148964)
# minresid_iteration_0: fail - [-0.18,-0.09] using coverages from [-0.18,-0.09]; initial residual was 7.007293862857086e+36 (residual = 22813467.35148964)
# minresid_iteration_1: success - [-0.18,-0.09] using coverages from [-0.18, 0.27]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 188966.24849911281)
# minresid_iteration_0: fail - [-0.18,-0.45] using coverages from [-0.18,-0.45]; initial residual was 5.198097795539066e+35 (residual = 188966.24849911281)
# minresid_iteration_1: success - [-0.18,-0.45] using coverages from [-0.18,-0.09]
# minresid_iteration_0: success - [-0.18,-0.82] using coverages from [-0.18,-0.82]
# minresid_iteration_0: success - [-0.18,-1.18] using coverages from [-0.18,-1.18]
# minresid_iteration_0: success - [-0.18,-1.55] using coverages from [-0.18,-1.55]
# minresid_iteration_0: success - [-0.18,-1.91] using coverages from [-0.18,-1.91]
# minresid_iteration_0: success - [-0.18,-2.27] using coverages from [-0.18,-2.27]
# minresid_iteration_0: success - [-0.18,-2.64] using coverages from [-0.18,-2.64]
# minresid_iteration_0: success - [-0.18,-3.00] using coverages from [-0.18,-3.00]
# minresid_iteration_0: success - [-0.45, 1.00] using coverages from [-0.45, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 47802377.42307855)
# minresid_iteration_0: fail - [-0.45, 0.64] using coverages from [-0.45, 0.64]; initial residual was 8.385447443333862e+37 (residual = 47802377.42307855)
# minresid_iteration_1: success - [-0.45, 0.64] using coverages from [-0.45, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1658784.2058553298)
# minresid_iteration_0: fail - [-0.45, 0.27] using coverages from [-0.45, 0.27]; initial residual was 6.221594543083349e+36 (residual = 1658784.2058553298)
# minresid_iteration_1: success - [-0.45, 0.27] using coverages from [-0.45, 0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 53460.935130162274)
# minresid_iteration_0: fail - [-0.45,-0.09] using coverages from [-0.45,-0.09]; initial residual was 4.615292919627162e+35 (residual = 53460.935130162274)
# minresid_iteration_1: success - [-0.45,-0.09] using coverages from [-0.45, 0.27]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 803.2365768550277)
# minresid_iteration_0: fail - [-0.45,-0.45] using coverages from [-0.45,-0.45]; initial residual was 3.423122299138778e+34 (residual = 803.2365768550277)
# minresid_iteration_1: success - [-0.45,-0.45] using coverages from [-0.45,-0.09]
# minresid_iteration_0: success - [-0.45,-0.82] using coverages from [-0.45,-0.82]
# minresid_iteration_0: success - [-0.45,-1.18] using coverages from [-0.45,-1.18]
# minresid_iteration_0: success - [-0.45,-1.55] using coverages from [-0.45,-1.55]
# minresid_iteration_0: success - [-0.45,-1.91] using coverages from [-0.45,-1.91]
# minresid_iteration_0: success - [-0.45,-2.27] using coverages from [-0.45,-2.27]
# minresid_iteration_0: success - [-0.45,-2.64] using coverages from [-0.45,-2.64]
# minresid_iteration_0: success - [-0.45,-3.00] using coverages from [-0.45,-3.00]
# minresid_iteration_0: success - [-0.73, 1.00] using coverages from [-0.73, 1.00]
# minresid_iteration_0: success - [-0.73, 0.64] using coverages from [-0.73, 0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 3564.8026158540565)
# minresid_iteration_0: fail - [-0.73, 0.27] using coverages from [-0.73, 0.27]; initial residual was 4.097802846037729e+35 (residual = 3564.8026158540565)
# minresid_iteration_1: success - [-0.73, 0.27] using coverages from [-0.73, 0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 119.8065911751348)
# minresid_iteration_0: fail - [-0.73,-0.09] using coverages from [-0.73,-0.09]; initial residual was 3.039766387933044e+34 (residual = 119.8065911751348)
# minresid_iteration_1: success - [-0.73,-0.09] using coverages from [-0.73, 0.27]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 2.652940824026076)
# minresid_iteration_0: fail - [-0.73,-0.45] using coverages from [-0.73,-0.45]; initial residual was 2.2457140878092605e+33 (residual = 2.652940824026076)
# minresid_iteration_1: success - [-0.73,-0.45] using coverages from [-0.73,-0.09]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 0.006566847282290317)
# minresid_iteration_0: fail - [-0.73,-0.82] using coverages from [-0.73,-0.82]; initial residual was 1.3755454021221648e+32 (residual = 0.006566847282290317)
# minresid_iteration_1: success - [-0.73,-0.82] using coverages from [-0.73,-0.45]
# minresid_iteration_0: success - [-0.73,-1.18] using coverages from [-0.73,-1.18]
# minresid_iteration_0: success - [-0.73,-1.55] using coverages from [-0.73,-1.55]
# minresid_iteration_0: success - [-0.73,-1.91] using coverages from [-0.73,-1.91]
# minresid_iteration_0: success - [-0.73,-2.27] using coverages from [-0.73,-2.27]
# minresid_iteration_0: success - [-0.73,-2.64] using coverages from [-0.73,-2.64]
# minresid_iteration_0: success - [-0.73,-3.00] using coverages from [-0.73,-3.00]
# minresid_iteration_0: success - [-1.00, 1.00] using coverages from [-1.00, 1.00]
# minresid_iteration_0: success - [-1.00, 0.64] using coverages from [-1.00, 0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 7.647576230077455)
# minresid_iteration_0: fail - [-1.00, 0.27] using coverages from [-1.00, 0.27]; initial residual was 2.6990427039227775e+34 (residual = 7.647576230077455)
# Damping step size exceeded max_damping.
# rootfinding_iteration_4: cancel - stationary point or singular jacobian (residual = 2.3883254265018187e-09)
# minresid_iteration_1: fail - [-1.00, 0.27] using coverages from [-1.00, 0.64]; initial residual was 71.63117460767138 (residual = 2.3883254265018187e-09)
# minresid_iteration_2: success - [-1.00, 0.27] using coverages from [-0.73, 0.27]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 0.2621655791705076)
# minresid_iteration_0: fail - [-1.00,-0.09] using coverages from [-1.00,-0.09]; initial residual was 1.9990919824786716e+33 (residual = 0.2621655791705076)
# minresid_iteration_1: success - [-1.00,-0.09] using coverages from [-1.00, 0.27]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 0.0072624193236880226)
# minresid_iteration_0: fail - [-1.00,-0.45] using coverages from [-1.00,-0.45]; initial residual was 1.3918932492494038e+32 (residual = 0.0072624193236880226)
# minresid_iteration_1: success - [-1.00,-0.45] using coverages from [-1.00,-0.09]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 4.1143092825322396e-05)
# minresid_iteration_0: fail - [-1.00,-0.82] using coverages from [-1.00,-0.82]; initial residual was 3.0545779532134555e+31 (residual = 4.1143092825322396e-05)
# minresid_iteration_1: success - [-1.00,-0.82] using coverages from [-1.00,-0.45]
# minresid_iteration_0: success - [-1.00,-1.18] using coverages from [-1.00,-1.18]
# minresid_iteration_0: success - [-1.00,-1.55] using coverages from [-1.00,-1.55]
# minresid_iteration_0: success - [-1.00,-1.91] using coverages from [-1.00,-1.91]
# minresid_iteration_0: success - [-1.00,-2.27] using coverages from [-1.00,-2.27]
# minresid_iteration_0: success - [-1.00,-2.64] using coverages from [-1.00,-2.64]
# minresid_iteration_0: success - [-1.00,-3.00] using coverages from [-1.00,-3.00]
# mapper_iteration_1: status - 0 points do not have valid solution.
# initial_evaluation: success - initial guess at point [ 2.00, 1.00]
# initial_evaluation: success - initial guess at point [ 2.00, 0.64]
# initial_evaluation: success - initial guess at point [ 2.00, 0.27]
# initial_evaluation: success - initial guess at point [ 2.00,-0.09]
# initial_evaluation: success - initial guess at point [ 2.00,-0.45]
# initial_evaluation: success - initial guess at point [ 2.00,-0.82]
# initial_evaluation: success - initial guess at point [ 2.00,-1.18]
# initial_evaluation: success - initial guess at point [ 2.00,-1.55]
# initial_evaluation: success - initial guess at point [ 2.00,-1.91]
# initial_evaluation: success - initial guess at point [ 2.00,-2.27]
# initial_evaluation: success - initial guess at point [ 2.00,-2.64]
# initial_evaluation: success - initial guess at point [ 2.00,-3.00]
# initial_evaluation: success - initial guess at point [ 1.73, 1.00]
# initial_evaluation: success - initial guess at point [ 1.73, 0.64]
# initial_evaluation: success - initial guess at point [ 1.73, 0.27]
# initial_evaluation: success - initial guess at point [ 1.73,-0.09]
# initial_evaluation: success - initial guess at point [ 1.73,-0.45]
# initial_evaluation: success - initial guess at point [ 1.73,-0.82]
# initial_evaluation: success - initial guess at point [ 1.73,-1.18]
# initial_evaluation: success - initial guess at point [ 1.73,-1.55]
# initial_evaluation: success - initial guess at point [ 1.73,-1.91]
# initial_evaluation: success - initial guess at point [ 1.73,-2.27]
# initial_evaluation: success - initial guess at point [ 1.73,-2.64]
# initial_evaluation: success - initial guess at point [ 1.73,-3.00]
# initial_evaluation: success - initial guess at point [ 1.45, 1.00]
# initial_evaluation: success - initial guess at point [ 1.45, 0.64]
# initial_evaluation: success - initial guess at point [ 1.45, 0.27]
# initial_evaluation: success - initial guess at point [ 1.45,-0.09]
# initial_evaluation: success - initial guess at point [ 1.45,-0.45]
# initial_evaluation: success - initial guess at point [ 1.45,-0.82]
# initial_evaluation: success - initial guess at point [ 1.45,-1.18]
# initial_evaluation: success - initial guess at point [ 1.45,-1.55]
# initial_evaluation: success - initial guess at point [ 1.45,-1.91]
# initial_evaluation: success - initial guess at point [ 1.45,-2.27]
# initial_evaluation: success - initial guess at point [ 1.45,-2.64]
# initial_evaluation: success - initial guess at point [ 1.45,-3.00]
# initial_evaluation: success - initial guess at point [ 1.18, 1.00]
# initial_evaluation: success - initial guess at point [ 1.18, 0.64]
# initial_evaluation: success - initial guess at point [ 1.18, 0.27]
# initial_evaluation: success - initial guess at point [ 1.18,-0.09]
# initial_evaluation: success - initial guess at point [ 1.18,-0.45]
# initial_evaluation: success - initial guess at point [ 1.18,-0.82]
# initial_evaluation: success - initial guess at point [ 1.18,-1.18]
# initial_evaluation: success - initial guess at point [ 1.18,-1.55]
# initial_evaluation: success - initial guess at point [ 1.18,-1.91]
# initial_evaluation: success - initial guess at point [ 1.18,-2.27]
# initial_evaluation: success - initial guess at point [ 1.18,-2.64]
# initial_evaluation: success - initial guess at point [ 1.18,-3.00]
# initial_evaluation: success - initial guess at point [ 0.91, 1.00]
# initial_evaluation: success - initial guess at point [ 0.91, 0.64]
# initial_evaluation: success - initial guess at point [ 0.91, 0.27]
# initial_evaluation: success - initial guess at point [ 0.91,-0.09]
# initial_evaluation: success - initial guess at point [ 0.91,-0.45]
# initial_evaluation: success - initial guess at point [ 0.91,-0.82]
# initial_evaluation: success - initial guess at point [ 0.91,-1.18]
# initial_evaluation: success - initial guess at point [ 0.91,-1.55]
# initial_evaluation: success - initial guess at point [ 0.91,-1.91]
# initial_evaluation: success - initial guess at point [ 0.91,-2.27]
# initial_evaluation: success - initial guess at point [ 0.91,-2.64]
# initial_evaluation: success - initial guess at point [ 0.91,-3.00]
# initial_evaluation: success - initial guess at point [ 0.64, 1.00]
# initial_evaluation: success - initial guess at point [ 0.64, 0.64]
# initial_evaluation: success - initial guess at point [ 0.64, 0.27]
# initial_evaluation: success - initial guess at point [ 0.64,-0.09]
# initial_evaluation: success - initial guess at point [ 0.64,-0.45]
# initial_evaluation: success - initial guess at point [ 0.64,-0.82]
# initial_evaluation: success - initial guess at point [ 0.64,-1.18]
# initial_evaluation: success - initial guess at point [ 0.64,-1.55]
# initial_evaluation: success - initial guess at point [ 0.64,-1.91]
# initial_evaluation: success - initial guess at point [ 0.64,-2.27]
# initial_evaluation: success - initial guess at point [ 0.64,-2.64]
# initial_evaluation: success - initial guess at point [ 0.64,-3.00]
# initial_evaluation: success - initial guess at point [ 0.36, 1.00]
# initial_evaluation: success - initial guess at point [ 0.36, 0.64]
# initial_evaluation: success - initial guess at point [ 0.36, 0.27]
# initial_evaluation: success - initial guess at point [ 0.36,-0.09]
# initial_evaluation: success - initial guess at point [ 0.36,-0.45]
# initial_evaluation: success - initial guess at point [ 0.36,-0.82]
# initial_evaluation: success - initial guess at point [ 0.36,-1.18]
# initial_evaluation: success - initial guess at point [ 0.36,-1.55]
# initial_evaluation: success - initial guess at point [ 0.36,-1.91]
# initial_evaluation: success - initial guess at point [ 0.36,-2.27]
# initial_evaluation: success - initial guess at point [ 0.36,-2.64]
# initial_evaluation: success - initial guess at point [ 0.36,-3.00]
# initial_evaluation: success - initial guess at point [ 0.09, 1.00]
# initial_evaluation: success - initial guess at point [ 0.09, 0.64]
# initial_evaluation: success - initial guess at point [ 0.09, 0.27]
# initial_evaluation: success - initial guess at point [ 0.09,-0.09]
# initial_evaluation: success - initial guess at point [ 0.09,-0.45]
# initial_evaluation: success - initial guess at point [ 0.09,-0.82]
# initial_evaluation: success - initial guess at point [ 0.09,-1.18]
# initial_evaluation: success - initial guess at point [ 0.09,-1.55]
# initial_evaluation: success - initial guess at point [ 0.09,-1.91]
# initial_evaluation: success - initial guess at point [ 0.09,-2.27]
# initial_evaluation: success - initial guess at point [ 0.09,-2.64]
# initial_evaluation: success - initial guess at point [ 0.09,-3.00]
# initial_evaluation: success - initial guess at point [-0.18, 1.00]
# initial_evaluation: success - initial guess at point [-0.18, 0.64]
# initial_evaluation: success - initial guess at point [-0.18, 0.27]
# initial_evaluation: success - initial guess at point [-0.18,-0.09]
# initial_evaluation: success - initial guess at point [-0.18,-0.45]
# initial_evaluation: success - initial guess at point [-0.18,-0.82]
# initial_evaluation: success - initial guess at point [-0.18,-1.18]
# initial_evaluation: success - initial guess at point [-0.18,-1.55]
# initial_evaluation: success - initial guess at point [-0.18,-1.91]
# initial_evaluation: success - initial guess at point [-0.18,-2.27]
# initial_evaluation: success - initial guess at point [-0.18,-2.64]
# initial_evaluation: success - initial guess at point [-0.18,-3.00]
# initial_evaluation: success - initial guess at point [-0.45, 1.00]
# initial_evaluation: success - initial guess at point [-0.45, 0.64]
# initial_evaluation: success - initial guess at point [-0.45, 0.27]
# initial_evaluation: success - initial guess at point [-0.45,-0.09]
# initial_evaluation: success - initial guess at point [-0.45,-0.45]
# initial_evaluation: success - initial guess at point [-0.45,-0.82]
# initial_evaluation: success - initial guess at point [-0.45,-1.18]
# initial_evaluation: success - initial guess at point [-0.45,-1.55]
# initial_evaluation: success - initial guess at point [-0.45,-1.91]
# initial_evaluation: success - initial guess at point [-0.45,-2.27]
# initial_evaluation: success - initial guess at point [-0.45,-2.64]
# initial_evaluation: success - initial guess at point [-0.45,-3.00]
# initial_evaluation: success - initial guess at point [-0.73, 1.00]
# initial_evaluation: success - initial guess at point [-0.73, 0.64]
# initial_evaluation: success - initial guess at point [-0.73, 0.27]
# initial_evaluation: success - initial guess at point [-0.73,-0.09]
# initial_evaluation: success - initial guess at point [-0.73,-0.45]
# initial_evaluation: success - initial guess at point [-0.73,-0.82]
# initial_evaluation: success - initial guess at point [-0.73,-1.18]
# initial_evaluation: success - initial guess at point [-0.73,-1.55]
# initial_evaluation: success - initial guess at point [-0.73,-1.91]
# initial_evaluation: success - initial guess at point [-0.73,-2.27]
# initial_evaluation: success - initial guess at point [-0.73,-2.64]
# initial_evaluation: success - initial guess at point [-0.73,-3.00]
# initial_evaluation: success - initial guess at point [-1.00, 1.00]
# initial_evaluation: success - initial guess at point [-1.00, 0.64]
# initial_evaluation: success - initial guess at point [-1.00, 0.27]
# initial_evaluation: success - initial guess at point [-1.00,-0.09]
# initial_evaluation: success - initial guess at point [-1.00,-0.45]
# initial_evaluation: success - initial guess at point [-1.00,-0.82]
# initial_evaluation: success - initial guess at point [-1.00,-1.18]
# initial_evaluation: success - initial guess at point [-1.00,-1.55]
# initial_evaluation: success - initial guess at point [-1.00,-1.91]
# initial_evaluation: success - initial guess at point [-1.00,-2.27]
# initial_evaluation: success - initial guess at point [-1.00,-2.64]
# initial_evaluation: success - initial guess at point [-1.00,-3.00]
# mapper_iteration_0: status - 0 points do not have valid solution.
# C:\Users\DELL\AppData\Roaming\Python\Python310\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# C:\Users\DELL\AppData\Roaming\Python\Python310\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# C:\Users\DELL\AppData\Roaming\Python\Python310\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# C:\Users\DELL\AppData\Roaming\Python\Python310\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# C:\Users\DELL\AppData\Roaming\Python\Python310\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# C:\Users\DELL\AppData\Roaming\Python\Python310\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)

# %%
from ase.calculators.calculator import InputError
from glob import glob
import sys
from catmap.model import ReactionModel

model.output_variables += ['production_rate','rate','rate_control','coverage','selectivity_control','rxn_order']

output_variable = 'production_rate'
logfile = glob('*.log')
if len(logfile) > 1:
    raise InputError('Ambiguous logfile. Ensure that only one file ends with .log')
model = ReactionModel(setup_file=logfile[0])

if output_variable == 'rate_control':
    dim = 2
else:
    dim = 1

labels = model.output_labels['production_rate']

def flatten_2d(output):
    "Helper function for flattening rate_control output"
    flat = []
    for x in output:
        flat+= x
    return flat

#flatten rate_control labels
if output_variable == 'rate_control':
    flat_labels = []
    for i in labels[0]:
        for j in labels[1]:
            flat_labels.append('d'+i+'/d'+j)
    labels = flat_labels

#flatten elementary-step specific labels
if output_variable in ['rate','rate_constant','forward_rate_constant','reverse_rate_constant']:
    str_labels = []
    for label in labels:
        states = ['+'.join(s) for s in label]
        if len(states) == 2:
            new_label = '<->'.join(states)
        else:
            new_label = states[0]+'<->'+states[1]+'->'+states[2]
        str_labels.append(new_label)
    labels = str_labels

table = '\t'.join(list(['descriptor-'+d for d in model.descriptor_names])+list(labels))+'\n'

for pt, output in getattr(model,output_variable+'_map'):
    if dim == 2:
        output = flatten_2d(output)
    table += '\t'.join([str(float(i)) for i in pt+output])+'\n'

f = open(output_variable+'_table.txt','w')
f.write(table)
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 import sys
#       4 from catmap.model import ReactionModel
# ----> 6 model.output_variables += ['production_rate','rate','rate_control','coverage','selectivity_control','rxn_order']
#       8 output_variable = 'production_rate'
#       9 logfile = glob('*.log')
#
# NameError: name 'model' is not defined

# %%
from catmap.model import ReactionModel

model = ReactionModel(setup_file='cracking.log')

#for MgO, cvgs in model.coverage_map:
   # print( 'descriptors:', MgO)
   #print( 'coverages', cvgs)
    
labels = model.output_labels['coverage']
for MgO ,cvg in model.coverage_map:
    print( 'descriptors',MgO)
    print( 'intermediates',labels)
    print( 'coverages', [float(c) for c in cvg])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 from catmap.model import ReactionModel
# ----> 3 model = ReactionModel(setup_file='cracking.log')
#       5 #for MgO, cvgs in model.coverage_map:
#       6    # print( 'descriptors:', MgO)
#       7    #print( 'coverages', cvgs)
#       9 labels = model.output_labels['coverage']
#
# File ~\AppData\Roaming\Python\Python310\site-packages\catmap\model.py:124, in ReactionModel.__init__(self, **kwargs)
#     120 if hasattr(self,'setup_file'): #parse in setup file.
#     121     #Note that the syntax is simply python variable definitions.
#     122     #This is NOT idiot proof.
#     123     self.model_name = self.setup_file.rsplit('.',1)[0]
# --> 124     self.load(self.setup_file)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\catmap\model.py:391, in ReactionModel.load(self, setup_file)
#     388 globs = {}
#     389 locs = defaults
# --> 391 exec(compile(open(setup_file, 'rb').read(), '<string>', 'exec'), globs, locs)
#     392 for var in locs.keys():
#     393     if var in self._classes:
#     394         #black magic to auto-import classes
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cracking.log'
