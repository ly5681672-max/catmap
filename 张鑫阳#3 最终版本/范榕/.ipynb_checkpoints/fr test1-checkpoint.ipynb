# %%
from catmap import ReactionModel

mkm_file = 'fr cracking.mkm'
model = ReactionModel(setup_file=mkm_file)
model.output_variables += ['production_rate','rate','rate_control','coverage','selectivity_control','rxn_order']
model.run()

from catmap import analyze
vm = analyze.VectorMap(model)
vm.plot_variable = 'rate' #tell the model which output to plot
vm.log_scale = True #rates should be plotted on a log-scale
vm.min = 1e-25 #minimum rate to plot
vm.max = 1e3 #maximum rate to plot
vm.plot(save='rate.pdf') #draw the plot and save it as "rate.pdf"

vm.unique_only = False
vm.plot(save='all_rates.pdf')
vm.unique_only = True

vm.production_rate_map = model.production_rate_map #attach map
vm.threshold = 1e-30 #do not plot rates below this
vm.plot_variable = 'production_rate'
vm.plot(save='production_rate.pdf')

vm.descriptor_labels = ['H adsorption [eV]', 'OH adsorption [eV]']
vm.subplots_adjust_kwargs = {'left':0.2,'right':0.8,'bottom':0.15}
vm.plot(save='pretty_production_rate.pdf')

vm.plot_variable = 'coverage'
vm.log_scale = False
vm.min = 0
vm.max = 1
vm.plot(save='coverage.pdf')

vm.include_labels = ['C5H9OH_s']
vm.plot(save='C5H9OH_coverage.pdf')

sa = analyze.ScalingAnalysis(model)
sa.plot(save='scaling.pdf')
# Out:
# mapper_iteration_0: status - 144 points do not have valid solution.
# Damping step size exceeded max_damping.
# rootfinding_iteration_2: cancel - stationary point or singular jacobian (residual = 18978533921.27903)
# minresid_iteration_0: fail - [ 2.00, 1.00] using coverages from [ 2.00, 1.00]; initial residual was 5.694556396828807e+19 (residual = 18978533921.27903)
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 75908590909.07184)
# minresid_iteration_1: fail - [ 2.00, 1.00] using coverages from [ 2.00, 1.00]; initial residual was 1.5126148374635676e+46 (residual = 75908590909.07184)
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 0.0032413364556409486)
# minresid_iteration_2: fail - [ 2.00, 1.00] using coverages from [ 2.00, 1.00]; initial residual was 3.0242537123849754e+18 (residual = 0.0032413364556409486)
# Unable to find solution at [ 2.00, 1.00] from current information. No nearby points for bisection.
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 5717976171300.805)
# minresid_iteration_0: fail - [ 2.00, 0.45] using coverages from [ 2.00, 0.45]; initial residual was 2.8563468047631004e+44 (residual = 5717976171300.805)
# Unable to find solution at [ 2.00, 0.45] from current information. No nearby points for bisection.
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 5.616906917617084e+16)
# minresid_iteration_0: fail - [ 2.00,-0.09] using coverages from [ 2.00,-0.09]; initial residual was 3.9298364056749435e+48 (residual = 5.616906917617084e+16)
# Unable to find solution at [ 2.00,-0.09] from current information. No nearby points for bisection.
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 2928578066569898.5)
# minresid_iteration_0: fail - [ 2.00,-0.64] using coverages from [ 2.00,-0.64]; initial residual was 5.40845376629578e+52 (residual = 2928578066569898.5)
# Unable to find solution at [ 2.00,-0.64] from current information. No nearby points for bisection.
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 676709.1932225772)
# minresid_iteration_0: fail - [ 2.00,-1.18] using coverages from [ 2.00,-1.18]; initial residual was 4.892706120309326e+50 (residual = 676709.1932225772)
# Unable to find solution at [ 2.00,-1.18] from current information. No nearby points for bisection.
# minresid_iteration_0: success - [ 2.00,-1.73] using coverages from [ 2.00,-1.73]
# minresid_iteration_0: success - [ 2.00,-2.27] using coverages from [ 2.00,-2.27]
# minresid_iteration_0: success - [ 2.00,-2.82] using coverages from [ 2.00,-2.82]
# minresid_iteration_0: success - [ 2.00,-3.36] using coverages from [ 2.00,-3.36]
# minresid_iteration_0: success - [ 2.00,-3.91] using coverages from [ 2.00,-3.91]
# minresid_iteration_0: success - [ 2.00,-4.45] using coverages from [ 2.00,-4.45]
# minresid_iteration_0: success - [ 2.00,-5.00] using coverages from [ 2.00,-5.00]
# minresid_iteration_0: success - [ 1.73, 1.00] using coverages from [ 1.73, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 478187021654492.1)
# minresid_iteration_0: fail - [ 1.73, 0.45] using coverages from [ 1.73, 0.45]; initial residual was 7.539677836757479e+45 (residual = 478187021654492.1)
# minresid_iteration_1: success - [ 1.73, 0.45] using coverages from [ 1.73, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 146703977569956.22)
# minresid_iteration_0: fail - [ 1.73,-0.09] using coverages from [ 1.73,-0.09]; initial residual was 1.0373285344946397e+50 (residual = 146703977569956.22)
# minresid_iteration_1: success - [ 1.73,-0.09] using coverages from [ 1.73, 0.45]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 229191892394138.9)
# minresid_iteration_0: fail - [ 1.73,-0.64] using coverages from [ 1.73,-0.64]; initial residual was 2.551045536556515e+53 (residual = 229191892394138.9)
# minresid_iteration_1: success - [ 1.73,-0.64] using coverages from [ 1.73,-0.09]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 544828.8007838504)
# minresid_iteration_0: fail - [ 1.73,-1.18] using coverages from [ 1.73,-1.18]; initial residual was 1.853562684764808e+49 (residual = 544828.8007838504)
# minresid_iteration_1: success - [ 1.73,-1.18] using coverages from [ 1.73,-0.64]
# minresid_iteration_0: success - [ 1.73,-1.73] using coverages from [ 1.73,-1.73]
# minresid_iteration_0: success - [ 1.73,-2.27] using coverages from [ 1.73,-2.27]
# minresid_iteration_0: success - [ 1.73,-2.82] using coverages from [ 1.73,-2.82]
# minresid_iteration_0: success - [ 1.73,-3.36] using coverages from [ 1.73,-3.36]
# minresid_iteration_0: success - [ 1.73,-3.91] using coverages from [ 1.73,-3.91]
# minresid_iteration_0: success - [ 1.73,-4.45] using coverages from [ 1.73,-4.45]
# minresid_iteration_0: success - [ 1.73,-5.00] using coverages from [ 1.73,-5.00]
# minresid_iteration_0: success - [ 1.45, 1.00] using coverages from [ 1.45, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.6770563553831386e+17)
# minresid_iteration_0: fail - [ 1.45, 0.45] using coverages from [ 1.45, 0.45]; initial residual was 1.9901904693796793e+47 (residual = 1.6770563553831386e+17)
# minresid_iteration_1: success - [ 1.45, 0.45] using coverages from [ 1.45, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 11350575749665.367)
# minresid_iteration_0: fail - [ 1.45,-0.09] using coverages from [ 1.45,-0.09]; initial residual was 2.7381559367800646e+51 (residual = 11350575749665.367)
# minresid_iteration_1: success - [ 1.45,-0.09] using coverages from [ 1.45, 0.45]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 134834902952.68756)
# minresid_iteration_0: fail - [ 1.45,-0.64] using coverages from [ 1.45,-0.64]; initial residual was 9.664432519423173e+51 (residual = 134834902952.68756)
# minresid_iteration_1: success - [ 1.45,-0.64] using coverages from [ 1.45,-0.09]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 19966.498483985677)
# minresid_iteration_0: fail - [ 1.45,-1.18] using coverages from [ 1.45,-1.18]; initial residual was 7.022074373220632e+47 (residual = 19966.498483985677)
# minresid_iteration_1: success - [ 1.45,-1.18] using coverages from [ 1.45,-0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.206974768671925e-09)
# minresid_iteration_0: fail - [ 1.45,-1.73] using coverages from [ 1.45,-1.73]; initial residual was 5.103752499918158e+43 (residual = 1.206974768671925e-09)
# minresid_iteration_1: success - [ 1.45,-1.73] using coverages from [ 1.45,-1.18]
# minresid_iteration_0: success - [ 1.45,-2.27] using coverages from [ 1.45,-2.27]
# minresid_iteration_0: success - [ 1.45,-2.82] using coverages from [ 1.45,-2.82]
# minresid_iteration_0: success - [ 1.45,-3.36] using coverages from [ 1.45,-3.36]
# minresid_iteration_0: success - [ 1.45,-3.91] using coverages from [ 1.45,-3.91]
# minresid_iteration_0: success - [ 1.45,-4.45] using coverages from [ 1.45,-4.45]
# minresid_iteration_0: success - [ 1.45,-5.00] using coverages from [ 1.45,-5.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 594999917807680.1)
# minresid_iteration_0: fail - [ 1.18, 1.00] using coverages from [ 1.18, 1.00]; initial residual was 3.817137859243132e+44 (residual = 594999917807680.1)
# minresid_iteration_1: success - [ 1.18, 1.00] using coverages from [ 1.45, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 528938785643668.7)
# minresid_iteration_0: fail - [ 1.18, 0.45] using coverages from [ 1.18, 0.45]; initial residual was 5.253351920661615e+48 (residual = 528938785643668.7)
# minresid_iteration_1: success - [ 1.18, 0.45] using coverages from [ 1.18, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 5236194976122.6455)
# minresid_iteration_0: fail - [ 1.18,-0.09] using coverages from [ 1.18,-0.09]; initial residual was 7.227698539857657e+52 (residual = 5236194976122.6455)
# minresid_iteration_1: success - [ 1.18,-0.09] using coverages from [ 1.18, 0.45]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 79354993.38168909)
# minresid_iteration_0: fail - [ 1.18,-0.64] using coverages from [ 1.18,-0.64]; initial residual was 3.6612931672130974e+50 (residual = 79354993.38168909)
# minresid_iteration_1: success - [ 1.18,-0.64] using coverages from [ 1.18,-0.09]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 16.851084265482474)
# minresid_iteration_0: fail - [ 1.18,-1.18] using coverages from [ 1.18,-1.18]; initial residual was 2.660256861304795e+46 (residual = 16.851084265482474)
# minresid_iteration_1: success - [ 1.18,-1.18] using coverages from [ 1.18,-0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.1280814414606094e-09)
# minresid_iteration_0: fail - [ 1.18,-1.73] using coverages from [ 1.18,-1.73]; initial residual was 1.9335159036428495e+42 (residual = 1.1280814414606094e-09)
# minresid_iteration_1: success - [ 1.18,-1.73] using coverages from [ 1.18,-1.18]
# minresid_iteration_0: success - [ 1.18,-2.27] using coverages from [ 1.18,-2.27]
# minresid_iteration_0: success - [ 1.18,-2.82] using coverages from [ 1.18,-2.82]
# minresid_iteration_0: success - [ 1.18,-3.36] using coverages from [ 1.18,-3.36]
# minresid_iteration_0: success - [ 1.18,-3.91] using coverages from [ 1.18,-3.91]
# minresid_iteration_0: success - [ 1.18,-4.45] using coverages from [ 1.18,-4.45]
# minresid_iteration_0: success - [ 1.18,-5.00] using coverages from [ 1.18,-5.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 3.809498928835247e+17)
# minresid_iteration_0: fail - [ 0.91, 1.00] using coverages from [ 0.91, 1.00]; initial residual was 1.0075803703871745e+46 (residual = 3.809498928835247e+17)
# minresid_iteration_1: success - [ 0.91, 1.00] using coverages from [ 1.18, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 405306413596.43134)
# minresid_iteration_0: fail - [ 0.91, 0.45] using coverages from [ 0.91, 0.45]; initial residual was 1.3866866929094925e+50 (residual = 405306413596.43134)
# minresid_iteration_1: success - [ 0.91, 0.45] using coverages from [ 0.91, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 216139191091.83057)
# minresid_iteration_0: fail - [ 0.91,-0.09] using coverages from [ 0.91,-0.09]; initial residual was 1.9083958813502182e+53 (residual = 216139191091.83057)
# minresid_iteration_1: success - [ 0.91,-0.09] using coverages from [ 0.91, 0.45]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 46569.07953694934)
# minresid_iteration_0: fail - [ 0.91,-0.64] using coverages from [ 0.91,-0.64]; initial residual was 1.3870517103868405e+49 (residual = 46569.07953694934)
# minresid_iteration_1: success - [ 0.91,-0.64] using coverages from [ 0.91,-0.09]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 0.009907373394955843)
# minresid_iteration_0: fail - [ 0.91,-1.18] using coverages from [ 0.91,-1.18]; initial residual was 1.007813733860697e+45 (residual = 0.009907373394955843)
# minresid_iteration_1: success - [ 0.91,-1.18] using coverages from [ 0.91,-0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 3.5544011929945943e-10)
# minresid_iteration_0: fail - [ 0.91,-1.73] using coverages from [ 0.91,-1.73]; initial residual was 7.303658238089289e+40 (residual = 3.5544011929945943e-10)
# minresid_iteration_1: success - [ 0.91,-1.73] using coverages from [ 0.91,-1.18]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 2.603786184671165e-24)
# minresid_iteration_0: fail - [ 0.91,-2.27] using coverages from [ 0.91,-2.27]; initial residual was 9.044076538599537e+36 (residual = 2.603786184671165e-24)
# minresid_iteration_1: success - [ 0.91,-2.27] using coverages from [ 0.91,-1.73]
# minresid_iteration_0: success - [ 0.91,-2.82] using coverages from [ 0.91,-2.82]
# minresid_iteration_0: success - [ 0.91,-3.36] using coverages from [ 0.91,-3.36]
# minresid_iteration_0: success - [ 0.91,-3.91] using coverages from [ 0.91,-3.91]
# minresid_iteration_0: success - [ 0.91,-4.45] using coverages from [ 0.91,-4.45]
# minresid_iteration_0: success - [ 0.91,-5.00] using coverages from [ 0.91,-5.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1313860337651503.0)
# minresid_iteration_0: fail - [ 0.64, 1.00] using coverages from [ 0.64, 1.00]; initial residual was 2.659632007764978e+47 (residual = 1313860337651503.0)
# minresid_iteration_1: success - [ 0.64, 1.00] using coverages from [ 0.91, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 24171673021.31876)
# minresid_iteration_0: fail - [ 0.64, 0.45] using coverages from [ 0.64, 0.45]; initial residual was 3.660329658716841e+51 (residual = 24171673021.31876)
# minresid_iteration_1: success - [ 0.64, 0.45] using coverages from [ 0.64, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 126945639.39128464)
# minresid_iteration_0: fail - [ 0.64,-0.09] using coverages from [ 0.64,-0.09]; initial residual was 7.229805564564584e+51 (residual = 126945639.39128464)
# minresid_iteration_1: success - [ 0.64,-0.09] using coverages from [ 0.64, 0.45]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 27.287011106414404)
# minresid_iteration_0: fail - [ 0.64,-0.64] using coverages from [ 0.64,-0.64]; initial residual was 5.254734759762185e+47 (residual = 27.287011106414404)
# minresid_iteration_1: success - [ 0.64,-0.64] using coverages from [ 0.64,-0.09]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 5.696151998853411e-06)
# minresid_iteration_0: fail - [ 0.64,-1.18] using coverages from [ 0.64,-1.18]; initial residual was 3.8178172689101905e+43 (residual = 5.696151998853411e-06)
# minresid_iteration_1: success - [ 0.64,-1.18] using coverages from [ 0.64,-0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.3090755305824188e-12)
# minresid_iteration_0: fail - [ 0.64,-1.73] using coverages from [ 0.64,-1.73]; initial residual was 1.3632432704367925e+42 (residual = 1.3090755305824188e-12)
# minresid_iteration_1: success - [ 0.64,-1.73] using coverages from [ 0.64,-1.18]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.9844119712994866e-23)
# minresid_iteration_0: fail - [ 0.64,-2.27] using coverages from [ 0.64,-2.27]; initial residual was 3.0541641004763856e+48 (residual = 1.9844119712994866e-23)
# minresid_iteration_1: success - [ 0.64,-2.27] using coverages from [ 0.64,-1.73]
# minresid_iteration_0: success - [ 0.64,-2.82] using coverages from [ 0.64,-2.82]
# minresid_iteration_0: success - [ 0.64,-3.36] using coverages from [ 0.64,-3.36]
# minresid_iteration_0: success - [ 0.64,-3.91] using coverages from [ 0.64,-3.91]
# minresid_iteration_0: success - [ 0.64,-4.45] using coverages from [ 0.64,-4.45]
# minresid_iteration_0: success - [ 0.64,-5.00] using coverages from [ 0.64,-5.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 790514457858.5927)
# minresid_iteration_0: fail - [ 0.36, 1.00] using coverages from [ 0.36, 1.00]; initial residual was 7.020424995207602e+48 (residual = 790514457858.5927)
# minresid_iteration_1: success - [ 0.36, 1.00] using coverages from [ 0.64, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 8879128034.250048)
# minresid_iteration_0: fail - [ 0.36, 0.45] using coverages from [ 0.36, 0.45]; initial residual was 9.661889220529756e+52 (residual = 8879128034.250048)
# minresid_iteration_1: success - [ 0.36, 0.45] using coverages from [ 0.36, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 74526.960384821)
# minresid_iteration_0: fail - [ 0.36,-0.09] using coverages from [ 0.36,-0.09]; initial residual was 2.7389541662810196e+50 (residual = 74526.960384821)
# minresid_iteration_1: success - [ 0.36,-0.09] using coverages from [ 0.36, 0.45]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 0.015932329581251337)
# minresid_iteration_0: fail - [ 0.36,-0.64] using coverages from [ 0.36,-0.64]; initial residual was 1.9907143459451798e+46 (residual = 0.015932329581251337)
# minresid_iteration_1: success - [ 0.36,-0.64] using coverages from [ 0.36,-0.09]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 3.1903209953226987e-09)
# minresid_iteration_0: fail - [ 0.36,-1.18] using coverages from [ 0.36,-1.18]; initial residual was 1.4460089025354762e+42 (residual = 3.1903209953226987e-09)
# minresid_iteration_1: success - [ 0.36,-1.18] using coverages from [ 0.36,-0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 6.10738205131912e-16)
# minresid_iteration_0: fail - [ 0.36,-1.73] using coverages from [ 0.36,-1.73]; initial residual was 1.432825331509996e+42 (residual = 6.10738205131912e-16)
# minresid_iteration_1: success - [ 0.36,-1.73] using coverages from [ 0.36,-1.18]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 9.758137690272474e-23)
# minresid_iteration_0: fail - [ 0.36,-2.27] using coverages from [ 0.36,-2.27]; initial residual was 3.399299187027248e+49 (residual = 9.758137690272474e-23)
# minresid_iteration_1: success - [ 0.36,-2.27] using coverages from [ 0.36,-1.73]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.5191837531492578e-34)
# minresid_iteration_0: fail - [ 0.36,-2.82] using coverages from [ 0.36,-2.82]; initial residual was 7.96564762484613e+56 (residual = 1.5191837531492578e-34)
# minresid_iteration_1: success - [ 0.36,-2.82] using coverages from [ 0.36,-2.27]
# minresid_iteration_0: success - [ 0.36,-3.36] using coverages from [ 0.36,-3.36]
# minresid_iteration_0: success - [ 0.36,-3.91] using coverages from [ 0.36,-3.91]
# minresid_iteration_0: success - [ 0.36,-4.45] using coverages from [ 0.36,-4.45]
# minresid_iteration_0: success - [ 0.36,-5.00] using coverages from [ 0.36,-5.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 517262121.4839289)
# minresid_iteration_0: fail - [ 0.09, 1.00] using coverages from [ 0.09, 1.00]; initial residual was 1.8531273111811055e+50 (residual = 517262121.4839289)
# minresid_iteration_1: success - [ 0.09, 1.00] using coverages from [ 0.36, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 203056163.1220206)
# minresid_iteration_0: fail - [ 0.09, 0.45] using coverages from [ 0.09, 0.45]; initial residual was 1.4280843011850762e+53 (residual = 203056163.1220206)
# minresid_iteration_1: success - [ 0.09, 0.45] using coverages from [ 0.09, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 43.709081506521876)
# minresid_iteration_0: fail - [ 0.09,-0.09] using coverages from [ 0.09,-0.09]; initial residual was 1.0376309373704802e+49 (residual = 43.709081506521876)
# minresid_iteration_1: success - [ 0.09,-0.09] using coverages from [ 0.09, 0.45]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 9.227655924282023e-06)
# minresid_iteration_0: fail - [ 0.09,-0.64] using coverages from [ 0.09,-0.64]; initial residual was 7.54166248187424e+44 (residual = 9.227655924282023e-06)
# minresid_iteration_1: success - [ 0.09,-0.64] using coverages from [ 0.09,-0.09]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.7030893332942476e-12)
# minresid_iteration_0: fail - [ 0.09,-1.18] using coverages from [ 0.09,-1.18]; initial residual was 5.471462550353067e+40 (residual = 1.7030893332942476e-12)
# minresid_iteration_1: success - [ 0.09,-1.18] using coverages from [ 0.09,-0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.0008534061043526e-18)
# minresid_iteration_0: fail - [ 0.09,-1.73] using coverages from [ 0.09,-1.73]; initial residual was 1.4467871903999187e+42 (residual = 1.0008534061043526e-18)
# minresid_iteration_1: success - [ 0.09,-1.73] using coverages from [ 0.09,-1.18]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.1861300199207506e-23)
# minresid_iteration_0: fail - [ 0.09,-2.27] using coverages from [ 0.09,-2.27]; initial residual was 3.3992992661449774e+49 (residual = 1.1861300199207506e-23)
# minresid_iteration_1: success - [ 0.09,-2.27] using coverages from [ 0.09,-1.73]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.5041972036409761e-34)
# minresid_iteration_0: fail - [ 0.09,-2.82] using coverages from [ 0.09,-2.82]; initial residual was 7.965649663324784e+56 (residual = 1.5041972036409761e-34)
# minresid_iteration_1: success - [ 0.09,-2.82] using coverages from [ 0.09,-2.27]
# minresid_iteration_0: success - [ 0.09,-3.36] using coverages from [ 0.09,-3.36]
# minresid_iteration_0: success - [ 0.09,-3.91] using coverages from [ 0.09,-3.91]
# minresid_iteration_0: success - [ 0.09,-4.45] using coverages from [ 0.09,-4.45]
# minresid_iteration_0: success - [ 0.09,-5.00] using coverages from [ 0.09,-5.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 37822256.46582722)
# minresid_iteration_0: fail - [-0.18, 1.00] using coverages from [-0.18, 1.00]; initial residual was 4.8915568983083455e+51 (residual = 37822256.46582722)
# minresid_iteration_1: success - [-0.18, 1.00] using coverages from [ 0.09, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 119240.90815011726)
# minresid_iteration_0: fail - [-0.18, 0.45] using coverages from [-0.18, 0.45]; initial residual was 5.410183457360028e+51 (residual = 119240.90815011726)
# minresid_iteration_1: success - [-0.18, 0.45] using coverages from [-0.18, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 0.025575116159623473)
# minresid_iteration_0: fail - [-0.18,-0.09] using coverages from [-0.18,-0.09]; initial residual was 3.9309820347729045e+47 (residual = 0.025575116159623473)
# minresid_iteration_1: success - [-0.18,-0.09] using coverages from [-0.18, 0.45]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 5.248984511383719e-09)
# minresid_iteration_0: fail - [-0.18,-0.64] using coverages from [-0.18,-0.64]; initial residual was 2.85709863432623e+43 (residual = 5.248984511383719e-09)
# minresid_iteration_1: success - [-0.18,-0.64] using coverages from [-0.18,-0.09]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 9.00267712479283e-16)
# minresid_iteration_0: fail - [-0.18,-1.18] using coverages from [-0.18,-1.18]; initial residual was 2.0599695460399552e+39 (residual = 9.00267712479283e-16)
# minresid_iteration_1: success - [-0.18,-1.18] using coverages from [-0.18,-0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 3.419928594432441e-21)
# minresid_iteration_0: fail - [-0.18,-1.73] using coverages from [-0.18,-1.73]; initial residual was 1.44952056418964e+42 (residual = 3.419928594432441e-21)
# minresid_iteration_1: success - [-0.18,-1.73] using coverages from [-0.18,-1.18]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 2.1089282815548466e-26)
# minresid_iteration_0: fail - [-0.18,-2.27] using coverages from [-0.18,-2.27]; initial residual was 3.3992992775060345e+49 (residual = 2.1089282815548466e-26)
# minresid_iteration_1: success - [-0.18,-2.27] using coverages from [-0.18,-1.73]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.0673685652206012e-34)
# minresid_iteration_0: fail - [-0.18,-2.82] using coverages from [-0.18,-2.82]; initial residual was 7.965649669027538e+56 (residual = 1.0673685652206012e-34)
# minresid_iteration_1: success - [-0.18,-2.82] using coverages from [-0.18,-2.27]
# minresid_iteration_0: success - [-0.18,-3.36] using coverages from [-0.18,-3.36]
# minresid_iteration_0: success - [-0.18,-3.91] using coverages from [-0.18,-3.91]
# minresid_iteration_0: success - [-0.18,-4.45] using coverages from [-0.18,-4.45]
# minresid_iteration_0: success - [-0.18,-5.00] using coverages from [-0.18,-5.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 14870206.765773185)
# minresid_iteration_0: fail - [-0.45, 1.00] using coverages from [-0.45, 1.00]; initial residual was 1.2911864578869856e+53 (residual = 14870206.765773185)
# minresid_iteration_1: success - [-0.45, 1.00] using coverages from [-0.18, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 69.97570783377907)
# minresid_iteration_0: fail - [-0.45, 0.45] using coverages from [-0.45, 0.45]; initial residual was 2.049604846015229e+50 (residual = 69.97570783377907)
# minresid_iteration_1: success - [-0.45, 0.45] using coverages from [-0.45, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.4884656204120203e-05)
# minresid_iteration_0: fail - [-0.45,-0.09] using coverages from [-0.45,-0.09]; initial residual was 1.4892211864518155e+46 (residual = 1.4884656204120203e-05)
# minresid_iteration_1: success - [-0.45,-0.09] using coverages from [-0.45, 0.45]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 2.8775544556793814e-12)
# minresid_iteration_0: fail - [-0.45,-0.64] using coverages from [-0.45,-0.64]; initial residual was 1.0823889542510989e+42 (residual = 2.8775544556793814e-12)
# minresid_iteration_1: success - [-0.45,-0.64] using coverages from [-0.45,-0.09]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 8.156104138430791e-19)
# minresid_iteration_0: fail - [-0.45,-1.18] using coverages from [-0.45,-1.18]; initial residual was 7.558707576488484e+37 (residual = 8.156104138430791e-19)
# minresid_iteration_1: success - [-0.45,-1.18] using coverages from [-0.45,-0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.2062649003123439e-23)
# minresid_iteration_0: fail - [-0.45,-1.73] using coverages from [-0.45,-1.73]; initial residual was 1.450053190322444e+42 (residual = 1.2062649003123439e-23)
# minresid_iteration_1: success - [-0.45,-1.73] using coverages from [-0.45,-1.18]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.2517161298701257e-29)
# minresid_iteration_0: fail - [-0.45,-2.27] using coverages from [-0.45,-2.27]; initial residual was 3.3992992797073217e+49 (residual = 1.2517161298701257e-29)
# minresid_iteration_1: success - [-0.45,-2.27] using coverages from [-0.45,-1.73]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 2.077145489952402e-36)
# minresid_iteration_0: fail - [-0.45,-2.82] using coverages from [-0.45,-2.82]; initial residual was 7.965649669043512e+56 (residual = 2.077145489952402e-36)
# minresid_iteration_1: success - [-0.45,-2.82] using coverages from [-0.45,-2.27]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 2.7663114467683648e-49)
# minresid_iteration_0: fail - [-0.45,-3.36] using coverages from [-0.45,-3.36]; initial residual was 1.8671882969507193e+64 (residual = 2.7663114467683648e-49)
# minresid_iteration_1: success - [-0.45,-3.36] using coverages from [-0.45,-2.82]
# minresid_iteration_0: success - [-0.45,-3.91] using coverages from [-0.45,-3.91]
# minresid_iteration_0: success - [-0.45,-4.45] using coverages from [-0.45,-4.45]
# minresid_iteration_0: success - [-0.45,-5.00] using coverages from [-0.45,-5.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 187341.69550892626)
# minresid_iteration_0: fail - [-0.73, 1.00] using coverages from [-0.73, 1.00]; initial residual was 1.068326754480951e+53 (residual = 187341.69550892626)
# minresid_iteration_1: success - [-0.73, 1.00] using coverages from [-0.45, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 0.04100144963699276)
# minresid_iteration_0: fail - [-0.73, 0.45] using coverages from [-0.73, 0.45]; initial residual was 7.764764462986096e+48 (residual = 0.04100144963699276)
# minresid_iteration_1: success - [-0.73, 0.45] using coverages from [-0.73, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 8.558235532196293e-09)
# minresid_iteration_0: fail - [-0.73,-0.09] using coverages from [-0.73,-0.09]; initial residual was 5.641795667566732e+44 (residual = 8.558235532196293e-09)
# minresid_iteration_1: success - [-0.73,-0.09] using coverages from [-0.73, 0.45]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.5007494332218626e-15)
# minresid_iteration_0: fail - [-0.73,-0.64] using coverages from [-0.73,-0.64]; initial residual was 4.1005428115854006e+40 (residual = 1.5007494332218626e-15)
# minresid_iteration_1: success - [-0.73,-0.64] using coverages from [-0.73,-0.09]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 2.2166843946245277e-21)
# minresid_iteration_0: fail - [-0.73,-1.18] using coverages from [-0.73,-1.18]; initial residual was 2.434016196134472e+36 (residual = 2.2166843946245277e-21)
# minresid_iteration_1: success - [-0.73,-1.18] using coverages from [-0.73,-0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 3.4080334154811746e-26)
# minresid_iteration_0: fail - [-0.73,-1.73] using coverages from [-0.73,-1.73]; initial residual was 1.45015689639729e+42 (residual = 3.4080334154811746e-26)
# minresid_iteration_1: success - [-0.73,-1.73] using coverages from [-0.73,-1.18]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 7.357130347733281e-33)
# minresid_iteration_0: fail - [-0.73,-2.27] using coverages from [-0.73,-2.27]; initial residual was 3.399299280136886e+49 (residual = 7.357130347733281e-33)
# minresid_iteration_1: success - [-0.73,-2.27] using coverages from [-0.73,-1.73]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 1.5782726699058075e-39)
# minresid_iteration_0: fail - [-0.73,-2.82] using coverages from [-0.73,-2.82]; initial residual was 7.96564966904358e+56 (residual = 1.5782726699058075e-39)
# minresid_iteration_1: success - [-0.73,-2.82] using coverages from [-0.73,-2.27]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 2.6059935966110593e-49)
# minresid_iteration_0: fail - [-0.73,-3.36] using coverages from [-0.73,-3.36]; initial residual was 1.867188296951153e+64 (residual = 2.6059935966110593e-49)
# minresid_iteration_1: success - [-0.73,-3.36] using coverages from [-0.73,-2.82]
# minresid_iteration_0: success - [-0.73,-3.91] using coverages from [-0.73,-3.91]
# minresid_iteration_0: success - [-0.73,-4.45] using coverages from [-0.73,-4.45]
# minresid_iteration_0: success - [-0.73,-5.00] using coverages from [-0.73,-5.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 26.311273768258037)
# minresid_iteration_0: fail - [-1.00, 1.00] using coverages from [-1.00, 1.00]; initial residual was 4.047270689378419e+51 (residual = 26.311273768258037)
# minresid_iteration_1: success - [-1.00, 1.00] using coverages from [-0.73, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 2.3916129761426467e-05)
# minresid_iteration_0: fail - [-1.00, 0.45] using coverages from [-1.00, 0.45]; initial residual was 2.9416190775407498e+47 (residual = 2.3916129761426467e-05)
# minresid_iteration_1: success - [-1.00, 0.45] using coverages from [-1.00, 1.00]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 4.7929533251176495e-12)
# minresid_iteration_0: fail - [-1.00,-0.09] using coverages from [-1.00,-0.09]; initial residual was 2.1373492790708687e+43 (residual = 4.7929533251176495e-12)
# minresid_iteration_1: success - [-1.00,-0.09] using coverages from [-1.00, 0.45]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 9.148704887711056e-19)
# minresid_iteration_0: fail - [-1.00,-0.64] using coverages from [-1.00,-0.64]; initial residual was 1.55345522606137e+39 (residual = 9.148704887711056e-19)
# minresid_iteration_1: success - [-1.00,-0.64] using coverages from [-1.00,-0.09]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 7.94966511277388e-24)
# minresid_iteration_0: fail - [-1.00,-1.18] using coverages from [-1.00,-1.18]; initial residual was 5.655920914867753e+34 (residual = 7.94966511277388e-24)
# minresid_iteration_1: success - [-1.00,-1.18] using coverages from [-1.00,-0.64]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 2.003066845045687e-29)
# minresid_iteration_0: fail - [-1.00,-1.73] using coverages from [-1.00,-1.73]; initial residual was 1.4501770858432423e+42 (residual = 2.003066845045687e-29)
# minresid_iteration_1: success - [-1.00,-1.73] using coverages from [-1.00,-1.18]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 4.3265014533639776e-36)
# minresid_iteration_0: fail - [-1.00,-2.27] using coverages from [-1.00,-2.27]; initial residual was 3.3992992802572124e+49 (residual = 4.3265014533639776e-36)
# minresid_iteration_1: success - [-1.00,-2.27] using coverages from [-1.00,-1.73]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 9.338339373178449e-43)
# minresid_iteration_0: fail - [-1.00,-2.82] using coverages from [-1.00,-2.82]; initial residual was 7.965649669043655e+56 (residual = 9.338339373178449e-43)
# minresid_iteration_1: success - [-1.00,-2.82] using coverages from [-1.00,-2.27]
# Damping step size exceeded max_damping.
# rootfinding_iteration_3: cancel - stationary point or singular jacobian (residual = 5.679120741030957e-50)
# minresid_iteration_0: fail - [-1.00,-3.36] using coverages from [-1.00,-3.36]; initial residual was 1.8671882969511568e+64 (residual = 5.679120741030957e-50)
# minresid_iteration_1: success - [-1.00,-3.36] using coverages from [-1.00,-2.82]
# minresid_iteration_0: success - [-1.00,-3.91] using coverages from [-1.00,-3.91]
# minresid_iteration_0: success - [-1.00,-4.45] using coverages from [-1.00,-4.45]
# minresid_iteration_0: success - [-1.00,-5.00] using coverages from [-1.00,-5.00]
# mapper_iteration_1: status - 5 points do not have valid solution.
# minresid_iteration_0: success - [ 2.00, 1.00] using coverages from [ 1.73, 1.00]
# minresid_iteration_0: success - [ 2.00, 0.45] using coverages from [ 1.73, 0.45]
# minresid_iteration_0: success - [ 2.00,-0.09] using coverages from [ 1.73,-0.09]
# minresid_iteration_0: success - [ 2.00,-0.64] using coverages from [ 1.73,-0.64]
# minresid_iteration_0: success - [ 2.00,-1.18] using coverages from [ 2.00,-1.73]
# mapper_iteration_2: status - 0 points do not have valid solution.
# initial_evaluation: success - initial guess at point [ 2.00,-1.73]
# initial_evaluation: success - initial guess at point [ 2.00,-2.27]
# initial_evaluation: success - initial guess at point [ 2.00,-2.82]
# initial_evaluation: success - initial guess at point [ 2.00,-3.36]
# initial_evaluation: success - initial guess at point [ 2.00,-3.91]
# initial_evaluation: success - initial guess at point [ 2.00,-4.45]
# initial_evaluation: success - initial guess at point [ 2.00,-5.00]
# initial_evaluation: success - initial guess at point [ 1.73, 1.00]
# initial_evaluation: success - initial guess at point [ 1.73, 0.45]
# initial_evaluation: success - initial guess at point [ 1.73,-0.09]
# initial_evaluation: success - initial guess at point [ 1.73,-0.64]
# initial_evaluation: success - initial guess at point [ 1.73,-1.18]
# initial_evaluation: success - initial guess at point [ 1.73,-1.73]
# initial_evaluation: success - initial guess at point [ 1.73,-2.27]
# initial_evaluation: success - initial guess at point [ 1.73,-2.82]
# initial_evaluation: success - initial guess at point [ 1.73,-3.36]
# initial_evaluation: success - initial guess at point [ 1.73,-3.91]
# initial_evaluation: success - initial guess at point [ 1.73,-4.45]
# initial_evaluation: success - initial guess at point [ 1.73,-5.00]
# initial_evaluation: success - initial guess at point [ 1.45, 1.00]
# initial_evaluation: success - initial guess at point [ 1.45, 0.45]
# initial_evaluation: success - initial guess at point [ 1.45,-0.09]
# initial_evaluation: success - initial guess at point [ 1.45,-0.64]
# initial_evaluation: success - initial guess at point [ 1.45,-1.18]
# initial_evaluation: success - initial guess at point [ 1.45,-1.73]
# initial_evaluation: success - initial guess at point [ 1.45,-2.27]
# initial_evaluation: success - initial guess at point [ 1.45,-2.82]
# initial_evaluation: success - initial guess at point [ 1.45,-3.36]
# initial_evaluation: success - initial guess at point [ 1.45,-3.91]
# initial_evaluation: success - initial guess at point [ 1.45,-4.45]
# initial_evaluation: success - initial guess at point [ 1.45,-5.00]
# initial_evaluation: success - initial guess at point [ 1.18, 1.00]
# initial_evaluation: success - initial guess at point [ 1.18, 0.45]
# initial_evaluation: success - initial guess at point [ 1.18,-0.09]
# initial_evaluation: success - initial guess at point [ 1.18,-0.64]
# initial_evaluation: success - initial guess at point [ 1.18,-1.18]
# initial_evaluation: success - initial guess at point [ 1.18,-1.73]
# initial_evaluation: success - initial guess at point [ 1.18,-2.27]
# initial_evaluation: success - initial guess at point [ 1.18,-2.82]
# initial_evaluation: success - initial guess at point [ 1.18,-3.36]
# initial_evaluation: success - initial guess at point [ 1.18,-3.91]
# initial_evaluation: success - initial guess at point [ 1.18,-4.45]
# initial_evaluation: success - initial guess at point [ 1.18,-5.00]
# initial_evaluation: success - initial guess at point [ 0.91, 1.00]
# initial_evaluation: success - initial guess at point [ 0.91, 0.45]
# initial_evaluation: success - initial guess at point [ 0.91,-0.09]
# initial_evaluation: success - initial guess at point [ 0.91,-0.64]
# initial_evaluation: success - initial guess at point [ 0.91,-1.18]
# initial_evaluation: success - initial guess at point [ 0.91,-1.73]
# initial_evaluation: success - initial guess at point [ 0.91,-2.27]
# initial_evaluation: success - initial guess at point [ 0.91,-2.82]
# initial_evaluation: success - initial guess at point [ 0.91,-3.36]
# initial_evaluation: success - initial guess at point [ 0.91,-3.91]
# initial_evaluation: success - initial guess at point [ 0.91,-4.45]
# initial_evaluation: success - initial guess at point [ 0.91,-5.00]
# initial_evaluation: success - initial guess at point [ 0.64, 1.00]
# initial_evaluation: success - initial guess at point [ 0.64, 0.45]
# initial_evaluation: success - initial guess at point [ 0.64,-0.09]
# initial_evaluation: success - initial guess at point [ 0.64,-0.64]
# initial_evaluation: success - initial guess at point [ 0.64,-1.18]
# initial_evaluation: success - initial guess at point [ 0.64,-1.73]
# initial_evaluation: success - initial guess at point [ 0.64,-2.27]
# initial_evaluation: success - initial guess at point [ 0.64,-2.82]
# initial_evaluation: success - initial guess at point [ 0.64,-3.36]
# initial_evaluation: success - initial guess at point [ 0.64,-3.91]
# initial_evaluation: success - initial guess at point [ 0.64,-4.45]
# initial_evaluation: success - initial guess at point [ 0.64,-5.00]
# initial_evaluation: success - initial guess at point [ 0.36, 1.00]
# initial_evaluation: success - initial guess at point [ 0.36, 0.45]
# initial_evaluation: success - initial guess at point [ 0.36,-0.09]
# initial_evaluation: success - initial guess at point [ 0.36,-0.64]
# initial_evaluation: success - initial guess at point [ 0.36,-1.18]
# initial_evaluation: success - initial guess at point [ 0.36,-1.73]
# initial_evaluation: success - initial guess at point [ 0.36,-2.27]
# initial_evaluation: success - initial guess at point [ 0.36,-2.82]
# initial_evaluation: success - initial guess at point [ 0.36,-3.36]
# initial_evaluation: success - initial guess at point [ 0.36,-3.91]
# initial_evaluation: success - initial guess at point [ 0.36,-4.45]
# initial_evaluation: success - initial guess at point [ 0.36,-5.00]
# initial_evaluation: success - initial guess at point [ 0.09, 1.00]
# initial_evaluation: success - initial guess at point [ 0.09, 0.45]
# initial_evaluation: success - initial guess at point [ 0.09,-0.09]
# initial_evaluation: success - initial guess at point [ 0.09,-0.64]
# initial_evaluation: success - initial guess at point [ 0.09,-1.18]
# initial_evaluation: success - initial guess at point [ 0.09,-1.73]
# initial_evaluation: success - initial guess at point [ 0.09,-2.27]
# initial_evaluation: success - initial guess at point [ 0.09,-2.82]
# initial_evaluation: success - initial guess at point [ 0.09,-3.36]
# initial_evaluation: success - initial guess at point [ 0.09,-3.91]
# initial_evaluation: success - initial guess at point [ 0.09,-4.45]
# initial_evaluation: success - initial guess at point [ 0.09,-5.00]
# initial_evaluation: success - initial guess at point [-0.18, 1.00]
# initial_evaluation: success - initial guess at point [-0.18, 0.45]
# initial_evaluation: success - initial guess at point [-0.18,-0.09]
# initial_evaluation: success - initial guess at point [-0.18,-0.64]
# initial_evaluation: success - initial guess at point [-0.18,-1.18]
# initial_evaluation: success - initial guess at point [-0.18,-1.73]
# initial_evaluation: success - initial guess at point [-0.18,-2.27]
# initial_evaluation: success - initial guess at point [-0.18,-2.82]
# initial_evaluation: success - initial guess at point [-0.18,-3.36]
# initial_evaluation: success - initial guess at point [-0.18,-3.91]
# initial_evaluation: success - initial guess at point [-0.18,-4.45]
# initial_evaluation: success - initial guess at point [-0.18,-5.00]
# initial_evaluation: success - initial guess at point [-0.45, 1.00]
# initial_evaluation: success - initial guess at point [-0.45, 0.45]
# initial_evaluation: success - initial guess at point [-0.45,-0.09]
# initial_evaluation: success - initial guess at point [-0.45,-0.64]
# initial_evaluation: success - initial guess at point [-0.45,-1.18]
# initial_evaluation: success - initial guess at point [-0.45,-1.73]
# initial_evaluation: success - initial guess at point [-0.45,-2.27]
# initial_evaluation: success - initial guess at point [-0.45,-2.82]
# initial_evaluation: success - initial guess at point [-0.45,-3.36]
# initial_evaluation: success - initial guess at point [-0.45,-3.91]
# initial_evaluation: success - initial guess at point [-0.45,-4.45]
# initial_evaluation: success - initial guess at point [-0.45,-5.00]
# initial_evaluation: success - initial guess at point [-0.73, 1.00]
# initial_evaluation: success - initial guess at point [-0.73, 0.45]
# initial_evaluation: success - initial guess at point [-0.73,-0.09]
# initial_evaluation: success - initial guess at point [-0.73,-0.64]
# initial_evaluation: success - initial guess at point [-0.73,-1.18]
# initial_evaluation: success - initial guess at point [-0.73,-1.73]
# initial_evaluation: success - initial guess at point [-0.73,-2.27]
# initial_evaluation: success - initial guess at point [-0.73,-2.82]
# initial_evaluation: success - initial guess at point [-0.73,-3.36]
# initial_evaluation: success - initial guess at point [-0.73,-3.91]
# initial_evaluation: success - initial guess at point [-0.73,-4.45]
# initial_evaluation: success - initial guess at point [-0.73,-5.00]
# initial_evaluation: success - initial guess at point [-1.00, 1.00]
# initial_evaluation: success - initial guess at point [-1.00, 0.45]
# initial_evaluation: success - initial guess at point [-1.00,-0.09]
# initial_evaluation: success - initial guess at point [-1.00,-0.64]
# initial_evaluation: success - initial guess at point [-1.00,-1.18]
# initial_evaluation: success - initial guess at point [-1.00,-1.73]
# initial_evaluation: success - initial guess at point [-1.00,-2.27]
# initial_evaluation: success - initial guess at point [-1.00,-2.82]
# initial_evaluation: success - initial guess at point [-1.00,-3.36]
# initial_evaluation: success - initial guess at point [-1.00,-3.91]
# initial_evaluation: success - initial guess at point [-1.00,-4.45]
# initial_evaluation: success - initial guess at point [-1.00,-5.00]
# initial_evaluation: success - initial guess at point [ 2.00, 1.00]
# initial_evaluation: success - initial guess at point [ 2.00, 0.45]
# initial_evaluation: success - initial guess at point [ 2.00,-0.09]
# initial_evaluation: success - initial guess at point [ 2.00,-0.64]
# initial_evaluation: success - initial guess at point [ 2.00,-1.18]
# mapper_iteration_0: status - 0 points do not have valid solution.
# C:\Users\DELL\AppData\Roaming\Python\Python310\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# C:\Users\DELL\AppData\Roaming\Python\Python310\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# C:\Users\DELL\AppData\Roaming\Python\Python310\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# C:\Users\DELL\AppData\Roaming\Python\Python310\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# C:\Users\DELL\AppData\Roaming\Python\Python310\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# C:\Users\DELL\AppData\Roaming\Python\Python310\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)

# %%
from glob import glob
import sys
from catmap.model import ReactionModel

model.output_variables += ['production_rate','rate','rate_control','coverage','selectivity_control','rxn_order']

output_variable = 'production_rate'
logfile = glob('*.log')
if len(logfile) > 1:
    raise InputError('Ambiguous logfile. Ensure that only one file ends with .log')
model = ReactionModel(setup_file=logfile[0])

if output_variable == 'rate_control':
    dim = 2
else:
    dim = 1

labels = model.output_labels['production_rate']

def flatten_2d(output):
    "Helper function for flattening rate_control output"
    flat = []
    for x in output:
        flat+= x
    return flat

#flatten rate_control labels
if output_variable == 'rate_control':
    flat_labels = []
    for i in labels[0]:
        for j in labels[1]:
            flat_labels.append('d'+i+'/d'+j)
    labels = flat_labels

#flatten elementary-step specific labels
if output_variable in ['rate','rate_constant','forward_rate_constant','reverse_rate_constant']:
    str_labels = []
    for label in labels:
        states = ['+'.join(s) for s in label]
        if len(states) == 2:
            new_label = '<->'.join(states)
        else:
            new_label = states[0]+'<->'+states[1]+'->'+states[2]
        str_labels.append(new_label)
    labels = str_labels

table = '\t'.join(list(['descriptor-'+d for d in model.descriptor_names])+list(labels))+'\n'

for pt, output in getattr(model,output_variable+'_map'):
    if dim == 2:
        output = flatten_2d(output)
    table += '\t'.join([str(float(i)) for i in pt+output])+'\n'

f = open(output_variable+'_table.txt','w')
f.write(table)
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       2 import sys
#       3 from catmap.model import ReactionModel
# ----> 5 model.output_variables += ['production_rate','rate','rate_control','coverage','selectivity_control','rxn_order']
#       7 output_variable = 'production_rate'
#       8 logfile = glob('*.log')
#
# NameError: name 'model' is not defined

# %%
from catmap.model import ReactionModel

model = ReactionModel(setup_file='cracking.log')

#for MgO, cvgs in model.coverage_map:
   # print( 'descriptors:', MgO)
   #print( 'coverages', cvgs)
    
labels = model.output_labels['coverage']
for MgO ,cvg in model.coverage_map:
    print( 'descriptors',MgO)
    print( 'intermediates',labels)
    print( 'coverages', [float(c) for c in cvg])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 from catmap.model import ReactionModel
# ----> 3 model = ReactionModel(setup_file='cracking.log')
#       5 #for MgO, cvgs in model.coverage_map:
#       6    # print( 'descriptors:', MgO)
#       7    #print( 'coverages', cvgs)
#       9 labels = model.output_labels['coverage']
#
# File ~\AppData\Roaming\Python\Python310\site-packages\catmap\model.py:124, in ReactionModel.__init__(self, **kwargs)
#     120 if hasattr(self,'setup_file'): #parse in setup file.
#     121     #Note that the syntax is simply python variable definitions.
#     122     #This is NOT idiot proof.
#     123     self.model_name = self.setup_file.rsplit('.',1)[0]
# --> 124     self.load(self.setup_file)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\catmap\model.py:391, in ReactionModel.load(self, setup_file)
#     388 globs = {}
#     389 locs = defaults
# --> 391 exec(compile(open(setup_file, 'rb').read(), '<string>', 'exec'), globs, locs)
#     392 for var in locs.keys():
#     393     if var in self._classes:
#     394         #black magic to auto-import classes
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cracking.log'
