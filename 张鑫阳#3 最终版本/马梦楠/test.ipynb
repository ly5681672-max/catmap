# %%
from catmap import ReactionModel

mkm_file = 'MA.mkm'

model = ReactionModel(setup_file=mkm_file)

# 测试错误的地方
print("site_names =", model.solver.site_names)
print("adsorbate_names (n=%d) =" % len(model.solver.adsorbate_names), model.solver.adsorbate_names)
esites = len(model.solver.site_names) - 1
print("esites =", esites)
print("expected c0 length =", len(model.solver.adsorbate_names) + esites)

model.output_variables += ['production_rate','rate','rate_control','coverage','selectivity_control','rxn_order']
model.run()

from catmap import analyze
vm = analyze.VectorMap(model)
vm.plot_variable = 'rate' #tell the model which output to plot
vm.log_scale = True #rates should be plotted on a log-scale
vm.min = 1e-25 #minimum rate to plot
vm.max = 1e3 #maximum rate to plot
vm.plot(save='rate.pdf') #draw the plot and save it as "rate.pdf"

vm.unique_only = False
vm.plot(save='all_rates.pdf')
vm.unique_only = True

vm.production_rate_map = model.production_rate_map #attach map
vm.threshold = 1e-30 #do not plot rates below this
vm.plot_variable = 'production_rate'
vm.plot(save='production_rate.pdf')

vm.descriptor_labels = ['H reactivity [eV]', 'O reactivity [eV]']
vm.subplots_adjust_kwargs = {'left':0.2,'right':0.8,'bottom':0.15}
vm.plot(save='pretty_production_rate.pdf')

vm.plot_variable = 'coverage'
vm.log_scale = False
vm.min = 0
vm.max = 1
vm.plot(save='coverage.pdf')

vm.include_labels = ['O_s']
vm.plot(save='O_coverage.pdf')

sa = analyze.ScalingAnalysis(model)
sa.plot(save='scaling.pdf')
# Out:
# Input line {'surface_name': 'TiO2-101    101', 'site_name': 'C3H5O   -2.161', 'species_name': 'None', 'formation_energy': '[]', 'bulk_structure': '[]', 'frequencies': 'Input File Tutorial.'} does not have all required fields.  Ignoring.
# site_names = ('s', 'g')
# adsorbate_names (n=8) = ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# esites = 1
# expected c0 length = 9
# If you find CatMAP useful to your research, please cite both the following papers:
#
#  Medford, A. J., Shi, C., Hoffmann, M. J., Lausche, A. C., Fitzgibbon, S. R., Bligaard, T., & Nørskov, J. K. (2015). CatMAP: a software package for descriptor-based microkinetic mapping of catalytic trends. Catalysis Letters, 145, 794-807.
#  Vijay, S., H. Heenen, H., Singh, A. R., Chan, K., & Voss, J. (2024). Number of sites-based solver for determining coverages from steady-state mean-field micro-kinetic models. Journal of Computational Chemistry, 45(9), 546-551.
#
# header_evaluation: fail - could not save coverage_map = [[[np.float64(1.0), np.float64(0.0)], [mpf('0.000000081494532944580870003703043361901148948956826307494406672952144651493221770810057173111959796319672342447142746474305843631487102'), mpf('0.0000000000011780215953074399356348862598480636980111609074517755625646884222065349839189181107661433998994776784662831340042744177713769709'), mpf('0.00000000000000000035611042337885072782278146883874828145917948039293014745733445319368157716819946866361754355176729826376754597213062021981309978'), mpf('0.0000000012996742999414843868271570270989355944323921526218699997982391605811590742252208675101425489972145826369479652357838086889464317'), mpf('0.0000000000000000000000000043841459587426316177793154752271381284078324430593672662467409842

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 15
#      12 print("expected c0 length =", len(model.solver.adsorbate_names) + esites)
#      14 model.output_variables += ['production_rate','rate','rate_control','coverage','selectivity_control','rxn_order']
# ---> 15 model.run()
#      17 from catmap import analyze
#      18 vm = analyze.VectorMap(model)
#
# File G:\anaconda\Lib\site-packages\catmap\model.py:291, in ReactionModel.run(self, **kwargs)
#     287 # If a map exists, run descriptor space analysis last
#     288 # (so that single-point guesses are not discarded).
#     289 if not ran_dsa and (getattr(self, 'descriptor_ranges', None) and
#     290                     getattr(self, 'resolution', None)):
# --> 291     self.descriptor_space_analysis()
#     293 # Save long attrs in data_file.
#     294 for attr in dir(self):
#
# File G:\anaconda\Lib\site-packages\catmap\model.py:343, in ReactionModel.descriptor_space_analysis(self)
#     339 def descriptor_space_analysis(self):
#     340     """
#     341     Use mapper to create map/volcano-plot of rates/coverages.
#     342     """
# --> 343     self.mapper.get_output_map(self.descriptor_ranges,self.resolution)
#
# File G:\anaconda\Lib\site-packages\catmap\mappers\mapper_base.py:104, in MapperBase.get_output_map(self, descriptor_ranges, resolution, *args, **kwargs)
#     102 for out in self._output_variables:
#     103     if getattr(self,'get_'+out+'_map'):
# --> 104         val = getattr(self,'get_'+out+'_map')(
#     105                 descriptor_ranges,resolution,*args,**kwargs)
#     106         setattr(self,out+'_map',val)
#     107         ismapped = True
#
# File G:\anaconda\Lib\site-packages\catmap\mappers\min_resid_mapper.py:428, in MinResidMapper.get_coverage_map(self, descriptor_ranges, resolution, initial_guess_adsorbate_names)
#     426     self._coverage_map.append([point,point_coverages])
#     427 elif self.use_numbers_solver:
# --> 428     self.get_point_output(point,guess_coverage)
#     429     self._numbers_map.append([point, self._numbers])
#     430     self._coverage_map.append([point, self._coverage])
#
# File G:\anaconda\Lib\site-packages\catmap\mappers\mapper_base.py:80, in MapperBase.get_point_output(self, descriptors, *args, **kwargs)
#      77         val = getattr(self,'get_point_'+out)(descriptors,*args,**kwargs)
#      78         setattr(self,'_'+out,val)
# ---> 80 self.solver.set_output_attrs(params)
#      81 self.scaler.set_output_attrs(descriptors)
#      83 for out in self.output_variables:
#
# File G:\anaconda\Lib\site-packages\catmap\solvers\solver_base.py:85, in SolverBase.set_output_attrs(self, rxn_parameters)
#      81     self.output_labels['carbon_selectivity'] = self.gas_names
#      84 if 'rate_control' in self.output_variables:
# ---> 85     self._rate_control = self.get_rate_control(rxn_parameters)
#      86     self.output_labels['rate_control'] = [self.gas_names,self.parameter_names]
#      88 if 'selectivity_control' in self.output_variables:
#
# File G:\anaconda\Lib\site-packages\catmap\solvers\mean_field_solver.py:149, in MeanFieldSolver.get_rate_control(self, rxn_parameters)
#     147 try:
#     148     diff_idxs = range(len(self.adsorbate_names+self.transition_state_names))
# --> 149     dRdG = numerical_jacobian(self.get_turnover_frequency,rxn_parameters,self._matrix,eps,diff_idxs=diff_idxs)
#     150 except ValueError as strerror:
#     151     resid = str(strerror).rsplit('=',1)[1]
#
# File G:\anaconda\Lib\site-packages\catmap\functions.py:529, in numerical_jacobian(f, x, matrix, h, diff_idxs)
#     526 #using delta proportional to xj is more stable
#     527 #for very small numbers.
#     528 xj[j] += delta
# --> 529 Jj = (matrix(f(xj)) - fx)/(delta)
#     530 for i in range(m):
#     531     J[i,j] = Jj[i]
#
# File G:\anaconda\Lib\site-packages\catmap\solvers\mean_field_solver.py:76, in MeanFieldSolver.get_turnover_frequency(self, rxn_parameters, rates, verify_coverages)
#      74 rxn_parameters = list(rxn_parameters)
#      75 if rates is None:
# ---> 76     rates = self.get_rate(rxn_parameters,verify_coverages=verify_coverages)
#      78 def gas_to_idxs(gas):
#      79     idxs = []
#
# File G:\anaconda\Lib\site-packages\catmap\solvers\mean_field_solver.py:52, in MeanFieldSolver.get_rate(self, rxn_parameters, coverages, verify_coverages, **coverage_kwargs)
#      50 if self.use_numbers_solver:
#      51     numbers = self._numbers
# ---> 52     coverages = self.get_coverage(
#      53             rxn_parameters,numbers,**coverage_kwargs)
#      54 else:
#      55     coverages = self.get_coverage(
#      56             rxn_parameters,coverages,**coverage_kwargs)
#
# File G:\anaconda\Lib\site-packages\catmap\solvers\steady_state_solver.py:91, in SteadyStateSolver.get_coverage(self, rxn_parameters, c0, findrootArgs)
#      82 """Return coverages for given reaction parameters and coverage constraints.
#      83
#      84     :param rxn_parameters: Sequence of rxn_parameters
#    (...)
#      88     :param findrootArgs: *deprecated*
#      89 """
#      90 if self.adsorbate_interaction_model in [None,'ideal'] or self.interaction_strength == 0:
# ---> 91     return self.get_ideal_coverages(rxn_parameters,c0,True,findrootArgs)
#      92 else:
#      93     return self.get_interacting_coverages(rxn_parameters,c0,1.0,findrootArgs)
#
# File G:\anaconda\Lib\site-packages\catmap\solvers\steady_state_solver.py:299, in SteadyStateSolver.get_ideal_coverages(self, rxn_parameters, c0, refresh_rate_constants, findrootArgs)
#     297     return self.get_ode_solution_coverage(rxn_parameters,self.ideal_steady_state_function,c0)
#     298 if self.use_numbers_solver:
# --> 299     return self.get_steady_state_numbers(rxn_parameters, self.ideal_steady_state_function,
#     300             self.ideal_steady_state_jacobian, c0)
#     301 else:
#     302     return self.get_steady_state_coverage(rxn_parameters,self.ideal_steady_state_function,
#     303             self.ideal_steady_state_jacobian,c0,findrootArgs)
#
# File G:\anaconda\Lib\site-packages\catmap\solvers\numbers_solver.py:422, in SteadyStateNumbersSolver.get_steady_state_numbers(self, rxn_parameters, steady_state_fn, jacobian_fn, c0)
#     420 i = 1
#     421 converged = False
# --> 422 for data_iteration in iterations:
#     423     if self.DEBUG:
#     424         x, error, Jxnorm, Jxnorm_numer = data_iteration
#
# File G:\anaconda\Lib\site-packages\catmap\solvers\solver_base.py:588, in NewtonRootNumbers.__iter__(self)
#     586     prec = -1*int(mp.log10(self.precision)/2)
#     587     rcond = self._mpfloat(f'1e{prec}') * self.precision
# --> 588     Jx_plus = self.moore_penrose_inverse(M=Jx, rcond=self.rcond)
#     589     s = Jx_plus * fxn
#     591 # damping step size
#
# File G:\anaconda\Lib\site-packages\catmap\solvers\solver_base.py:427, in NewtonRootNumbers.moore_penrose_inverse(self, M, rcond)
#     425 """Determine the moore-penrose inverse of a matrix."""
#     426 # Take the SVD of M
# --> 427 U, S, V = self._math.svd_r(M)
#     428 if rcond:
#     429     cutoff = rcond * mp.fabs(S[0])
#
# File G:\anaconda\Lib\site-packages\mpmath\matrices\eigen_symmetric.py:1614, in svd_r(ctx, A, full_matrices, compute_uv, overwrite_a)
#    1612     A = A.copy()
#    1613 V = ctx.zeros(n, n)
# -> 1614 S = svd_r_raw(ctx, A, V, calc_u = True)
#    1616 if n > m:
#    1617     if full_matrices == False:
#
# File G:\anaconda\Lib\site-packages\mpmath\matrices\eigen_symmetric.py:1139, in svd_r_raw(ctx, A, V, calc_u)
#    1137         z = V[j+1,jj]
#    1138         V[j    ,jj]= x * c + z * s
# -> 1139         V[j+1  ,jj]= z * c - x * s
#    1140 z = ctx.hypot(f, h)
#    1141 S[j] = z
#
# File G:\anaconda\Lib\site-packages\mpmath\matrices\matrices.py:497, in _matrix.__setitem__(self, key, value)
#     494         else:
#     495             return self.ctx.zero
# --> 497 def __setitem__(self, key, value):
#     498     # setitem function for mp matrix class with slice index enabled
#     499     # it allows the following assingments
#     500     #  scalar to a slice of the matrix
#     501     # A[:,2:6] = 2.5
#     502     #  submatrix to matrix (the value matrix should be the same size as the slice size)
#     503     # A[3,:] = B   where A is n x m  and B is n x 1
#     504     # Convert vector to matrix indexing
#     505     if isinstance(key, int) or isinstance(key,slice):
#     506         # only sufficent for vectors
#     507         if self.__rows == 1:
#
# KeyboardInterrupt:

# %%
from ase.calculators.calculator import InputError
from glob import glob
import sys
from catmap.model import ReactionModel

model.output_variables += ['production_rate','rate','rate_control','coverage','selectivity_control','rxn_order']

output_variable = 'production_rate'
logfile = glob('*.log')
if len(logfile) > 1:
    raise InputError('Ambiguous logfile. Ensure that only one file ends with .log')
model = ReactionModel(setup_file=logfile[0])

if output_variable == 'rate_control':
    dim = 2
else:
    dim = 1

labels = model.output_labels['production_rate']

def flatten_2d(output):
    "Helper function for flattening rate_control output"
    flat = []
    for x in output:
        flat+= x
    return flat

#flatten rate_control labels
if output_variable == 'rate_control':
    flat_labels = []
    for i in labels[0]:
        for j in labels[1]:
            flat_labels.append('d'+i+'/d'+j)
    labels = flat_labels

#flatten elementary-step specific labels
if output_variable in ['rate','rate_constant','forward_rate_constant','reverse_rate_constant']:
    str_labels = []
    for label in labels:
        states = ['+'.join(s) for s in label]
        if len(states) == 2:
            new_label = '<->'.join(states)
        else:
            new_label = states[0]+'<->'+states[1]+'->'+states[2]
        str_labels.append(new_label)
    labels = str_labels

table = '\t'.join(list(['descriptor-'+d for d in model.descriptor_names])+list(labels))+'\n'

for pt, output in getattr(model,output_variable+'_map'):
    if dim == 2:
        output = flatten_2d(output)
    table += '\t'.join([str(float(i)) for i in pt+output])+'\n'

f = open(output_variable+'_table.txt','w')
f.write(table)
f.close()

# %%
from catmap.model import ReactionModel

model = ReactionModel(setup_file='MA.log')

#for MgO, cvgs in model.coverage_map:
   # print( 'descriptors:', MgO)
   #print( 'coverages', cvgs)
    
labels = model.output_labels['coverage']
for MgO ,cvg in model.coverage_map:
    print( 'descriptors',MgO)
    print( 'intermediates',labels)
    print( 'coverages', [float(c) for c in cvg])
