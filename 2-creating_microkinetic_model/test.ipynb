# %%
import page

# -*- coding: utf-8 -*-
# page.encoding='utf-8'

from catmap import ReactionModel

mkm_file = 'cracking.mkm'
model = ReactionModel(setup_file=mkm_file)
model.output_variables += ['production_rate','rate','rate_control','coverage','selectivity_control','rxn_order']
model.run()

from catmap import analyze
vm = analyze.VectorMap(model)
vm.plot_variable = 'rate' #tell the model which output to plot
vm.log_scale = True #rates should be plotted on a log-scale
vm.min = 1e-25 #minimum rate to plot
vm.max = 1e3 #maximum rate to plot
vm.plot(save='rate.pdf') #draw the plot and save it as "rate.pdf"

vm.unique_only = False
vm.plot(save='all_rates.pdf')
vm.unique_only = True

vm.production_rate_map = model.production_rate_map #attach map
vm.threshold = 1e-30 #do not plot rates below this
vm.plot_variable = 'production_rate'
vm.plot(save='production_rate.pdf')

vm.descriptor_labels = ['H reactivity [eV]', 'C2H5 reactivity [eV]']
vm.subplots_adjust_kwargs = {'left':0.2,'right':0.8,'bottom':0.15}
vm.plot(save='pretty_production_rate.pdf')

vm.plot_variable = 'coverage'
vm.log_scale = False
vm.min = 0
vm.max = 1
vm.plot(save='coverage.pdf')

vm.include_labels = ['C2H5_s']
vm.plot(save='C2H5_coverage.pdf')

sa = analyze.ScalingAnalysis(model)
sa.plot(save='scaling.pdf')
# Out:
# Input line {'surface_name': 'CeO2', 'site_name': '111', 'species_name': 'C3H5O', 'formation_energy': '-4.27', 'bulk_structure': 'None [] []', 'frequencies': 'Input File Tutorial.'} does not have all required fields.  Ignoring.
# Input line {'surface_name': 'CeO2', 'site_name': '111', 'species_name': 'C3H5O-H', 'formation_energy': '0.574', 'bulk_structure': 'None [] []', 'frequencies': 'Input File Tutorial.'} does not have all required fields.  Ignoring.
# Input line {'surface_name': 'CeO2', 'site_name': '111', 'species_name': 'C3H6', 'formation_energy': '-6.496', 'bulk_structure': 'None [] []', 'frequencies': 'Input File Tutorial.'} does not have all required fields.  Ignoring.
# Input line {'surface_name': 'CeO2', 'site_name': '111', 'species_name': 'C3H6O', 'formation_energy': '0.412', 'bulk_structure': 'None [] []', 'frequencies': 'Input File Tutorial.'} does not have all required fields.  Ignoring.
# Input line {'surface_name': 'CeO2', 'site_name': '111', 'species_name': 'CH3CHOCH-H', 'formation_energy': '1.1', 'bulk_structure': 'None []', 'frequencies': '[] Input File Tutorial.'} does not have all required fields.  Ignoring.
# Input line {'surface_name': 'CeO2', 'site_name': '111', 'species_name': 'H', 'formation_energy': '-1.096', 'bulk_structure': 'None []', 'frequencies': '[] Input File Tutorial.'} does not have all required fields.  Ignoring.
# Input line {'surface_name': 'CeO2', 'site_name': '111', 'species_name': 'H2', 'formation_energy': '1.137', 'bulk_structure': 'None []', 'frequencies': '[] Input File Tutorial.'} does not have all required fields.  Ignoring.
# Input line {'surface_name': 'CeO2', 'site_name': '111', 'species_name': 'H2O', 'formation_energy': '0.299', 'bulk_structure': 'None []', 'frequencies': '[] Input File Tutorial.'} does not have all required fields.  Ignoring.
# Input line {'surface_name': 'CeO2', 'site_name': '111', 'species_name': 'O', 'formation_energy': '0.667', 'bulk_structure': 'None []', 'frequencies': '[] Input File Tutorial.'} does not have all required fields.  Ignoring.
# Input line {'surface_name': 'CeO2', 'site_name': '111', 'species_name': 'O-H2', 'formation_energy': '2.498', 'bulk_structure': 'None []', 'frequencies': '[] Input File Tutorial.'} does not have all required fields.  Ignoring.
# Input line {'surface_name': 'CeO2', 'site_name': '111', 'species_name': 'OH', 'formation_energy': '-1.365', 'bulk_structure': 'None []', 'frequencies': '[] Input File Tutorial.'} does not have all required fields.  Ignoring.
# Input line {'surface_name': 'CeO2', 'site_name': '111', 'species_name': 'OH-H', 'formation_energy': '1.977', 'bulk_structure': 'None []', 'frequencies': '[] Input File Tutorial.'} does not have all required fields.  Ignoring.
# If you find CatMAP useful to your research, please cite both the following papers:
#
#  Medford, A. J., Shi, C., Hoffmann, M. J., Lausche, A. C., Fitzgibbon, S. R., Bligaard, T., & Nørskov, J. K. (2015). CatMAP: a software package for descriptor-based microkinetic mapping of catalytic trends. Catalysis Letters, 145, 794-807.
#  Vijay, S., H. Heenen, H., Singh, A. R., Chan, K., & Voss, J. (2024). Number of sites-based solver for determining coverages from steady-state mean-field micro-kinetic models. Journal of Computational Chemistry, 45(9), 546-551.
#
# header_evaluation: fail - could not save coverage_map = [[[np.float64(2.0), np.float64(2.0)], [mpf('0.00000001333579873040837242711471675937714054066209997595959681151452903513747740147874295581961743802707403867620792905561753415608029'), mpf('0.000000000000069793308105171483873991473275348258460591620473623354523770910982834535941249815615439993660277938528809553902466197448740247272'), mpf('0.00000000064568164029623651526895212111333582058343703407520385376336696058262124612229546025448013531665195008907324450136285436271118652'), mpf('0.00000000000000000000014361438496357874029827032844231644275907464875310402122057038016194294174738471659114962102446978847952376870389237345198859206'), mpf('0.0000000000000017820912008075298360947558947140225479863351256244074235477334921661114164505578584226533703345650346192575185947129227751377727'), mpf('0.000010422373333012100877734426971069413089452484682595937732021430595077907831011159199297539897656092365555800032865907424899442562'), mpf('0.0000000000000031710276317168552050165717824784387905794589266534024008575551047942870924059252795016300312650849934493190419174767638327867611'), mpf('0.9999895636451118707674320129354813685551833752215389201701823374784076461512699759251502371455040215702554282251046126166522104')]], [[np.float64(2.0), np.float64(1.4285714285714284)], [mpf('0.000000057484833860979179137087079238812447046815949352257602677700452890744581107267299039980592968400261753432389334619791185489134097'), mpf('0.0000000018811928260636825879200818784007733009686193150829172654019736981291680906069743956014813109621308249013305431557775114527129594'), mpf('0.00000000064568161057512348024884952202964461572597163262399727378948864886563941575787159836367431145055840534325165737105572795415423067'), mpf('0.000000000000000081385511152832792525965278997642148973320153849150906285757669380300923661954165593340752181961328186229549907554450932706090953'), mpf('0.00000000000044587330294211490156076665786427755610462612875364693749085987075994285122657095469462457298791023564212254627422158553916619806'), mpf('0.000010422372853264004109099314314039170505116302012465176994800037047122915895633025911230031105828449059940468160705902992754449073'), mpf('0.00000000000000010859248569433801609030324914024338644654425318049139185882816456344916854622159166233982055607692778584676314657383800730659534'), mpf('0.99998951761499237509696673335730593866023750474580718886532730649124863488812186674062495689269370048442842758096966432779554429')]], [[np.float64(2.0), np.float64(0.8571428571428568)], [mpf('0.00000024779168407651324973267584328729541814649798159969451378068857313702553141029433631390531505456980804042916266781471
761613091348309337041285667121655990086571386308829847181418302228668101'), mpf('0.0000000068371664960268000992555677151992351975677613357154250667502870345905112201683837483336537969872236047781853181159986008301057051')]], [[np.float64(2.0), np.float64(0.2857142857142856)], [mpf('0.0000022054938376753240380110567230502545648808463656002004124064815902832049419017685966694658328050637413948903281950425382884892117'), mpf('0.0000022054938376753240380110567233538269768435477715513231549241628852303895942644793637081050232314237001757953972757254372177417492'), mpf('0.000002205493837675324038011056723353826976843558932699621781669012099203100044620537662489855132538573658300128239614508633254895141'), mpf('0.0000022054938376753240380110567233538269768435589156074076621689637903792597116733699228128706778244175687112287037572143784075345081'), mpf('0.0000022054938 ...
#
#
# initial_evaluation: fail - initial guess at point [ 2.00, 2.00]
# initial_evaluation: fail - initial guess at point [ 2.00, 1.43]
# initial_evaluation: fail - initial guess at point [ 2.00, 0.86]
# initial_evaluation: fail - initial guess at point [ 2.00, 0.29]
# initial_evaluation: fail - initial guess at point [ 2.00,-0.29]
# initial_evaluation: fail - initial guess at point [ 2.00,-0.86]
# initial_evaluation: fail - initial guess at point [ 2.00,-1.43]
# initial_evaluation: fail - initial guess at point [ 2.00,-2.00]
# initial_evaluation: fail - initial guess at point [ 1.43, 2.00]
# initial_evaluation: fail - initial guess at point [ 1.43, 1.43]
# initial_evaluation: fail - initial guess at point [ 1.43, 0.86]
# initial_evaluation: fail - initial guess at point [ 1.43, 0.29]
# initial_evaluation: fail - initial guess at point [ 1.43,-0.29]
# initial_evaluation: fail - initial guess at point [ 1.43,-0.86]
# initial_evaluation: fail - initial guess at point [ 1.43,-1.43]
# initial_evaluation: fail - initial guess at point [ 1.43,-2.00]
# initial_evaluation: fail - initial guess at point [ 0.86, 2.00]
# initial_evaluation: fail - initial guess at point [ 0.86, 1.43]
# initial_evaluation: fail - initial guess at point [ 0.86, 0.86]
# initial_evaluation: fail - initial guess at point [ 0.86, 0.29]
# initial_evaluation: fail - initial guess at point [ 0.86,-0.29]
# initial_evaluation: fail - initial guess at point [ 0.86,-0.86]
# initial_evaluation: fail - initial guess at point [ 0.86,-1.43]
# initial_evaluation: fail - initial guess at point [ 0.86,-2.00]
# initial_evaluation: fail - initial guess at point [ 0.29, 2.00]
# initial_evaluation: fail - initial guess at point [ 0.29, 1.43]
# initial_evaluation: fail - initial guess at point [ 0.29, 0.86]
# initial_evaluation: fail - initial guess at point [ 0.29, 0.29]
# initial_evaluation: fail - initial guess at point [ 0.29,-0.29]
# initial_evaluation: fail - initial guess at point [ 0.29,-0.86]
# initial_evaluation: fail - initial guess at point [ 0.29,-1.43]
# initial_evaluation: fail - initial guess at point [ 0.29,-2.00]
# initial_evaluation: fail - initial guess at point [-0.29, 2.00]
# initial_evaluation: fail - initial guess at point [-0.29, 1.43]
# initial_evaluation: fail - initial guess at point [-0.29, 0.86]
# initial_evaluation: fail - initial guess at point [-0.29, 0.29]
# initial_evaluation: fail - initial guess at point [-0.29,-0.29]
# initial_evaluation: fail - initial guess at point [-0.29,-0.86]
# initial_evaluation: fail - initial guess at point [-0.29,-1.43]
# initial_evaluation: fail - initial guess at point [-0.29,-2.00]
# initial_evaluation: fail - initial guess at point [-0.86, 2.00]
# initial_evaluation: fail - initial guess at point [-0.86, 1.43]
# initial_evaluation: fail - initial guess at point [-0.86, 0.86]
# initial_evaluation: fail - initial guess at point [-0.86, 0.29]
# initial_evaluation: fail - initial guess at point [-0.86,-0.29]
# initial_evaluation: fail - initial guess at point [-0.86,-0.86]
# initial_evaluation: fail - initial guess at point [-0.86,-1.43]
# initial_evaluation: fail - initial guess at point [-0.86,-2.00]
# initial_evaluation: fail - initial guess at point [-1.43, 2.00]
# initial_evaluation: fail - initial guess at point [-1.43, 1.43]
# initial_evaluation: fail - initial guess at point [-1.43, 0.86]
# initial_evaluation: fail - initial guess at point [-1.43, 0.29]
# initial_evaluation: fail - initial guess at point [-1.43,-0.29]
# initial_evaluation: fail - initial guess at point [-1.43,-0.86]
# initial_evaluation: fail - initial guess at point [-1.43,-1.43]
# initial_evaluation: fail - initial guess at point [-1.43,-2.00]
# initial_evaluation: fail - initial guess at point [-2.00, 2.00]
# initial_evaluation: fail - initial guess at point [-2.00, 1.43]
# initial_evaluation: fail - initial guess at point [-2.00, 0.86]
# initial_evaluation: fail - initial guess at point [-2.00, 0.29]
# initial_evaluation: fail - initial guess at point [-2.00,-0.29]
# initial_evaluation: fail - initial guess at point [-2.00,-0.86]
# initial_evaluation: fail - initial guess at point [-2.00,-1.43]
# initial_evaluation: fail - initial guess at point [-2.00,-2.00]
# mapper_iteration_0: status - 64 points do not have valid solution.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File G:\anaconda\Lib\site-packages\catmap\scalers\generalized_linear_scaler.py:58, in GeneralizedLinearScaler.parameterize(self)
#      57 desc_val = desc_val['formation_energy'][s_id]
# ---> 58 desc_val = float(desc_val)
#      59 desc_list.append(desc_val)
#
# TypeError: float() argument must be a string or a real number, not 'NoneType'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 11
#       9 model = ReactionModel(setup_file=mkm_file)
#      10 model.output_variables += ['production_rate','rate','rate_control','coverage','selectivity_control','rxn_order']
# ---> 11 model.run()
#      13 from catmap import analyze
#      14 vm = analyze.VectorMap(model)
#
# File G:\anaconda\Lib\site-packages\catmap\model.py:291, in ReactionModel.run(self, **kwargs)
#     287 # If a map exists, run descriptor space analysis last
#     288 # (so that single-point guesses are not discarded).
#     289 if not ran_dsa and (getattr(self, 'descriptor_ranges', None) and
#     290                     getattr(self, 'resolution', None)):
# --> 291     self.descriptor_space_analysis()
#     293 # Save long attrs in data_file.
#     294 for attr in dir(self):
#
# File G:\anaconda\Lib\site-packages\catmap\model.py:343, in ReactionModel.descriptor_space_analysis(self)
#     339 def descriptor_space_analysis(self):
#     340     """
#     341     Use mapper to create map/volcano-plot of rates/coverages.
#     342     """
# --> 343     self.mapper.get_output_map(self.descriptor_ranges,self.resolution)
#
# File G:\anaconda\Lib\site-packages\catmap\mappers\mapper_base.py:104, in MapperBase.get_output_map(self, descriptor_ranges, resolution, *args, **kwargs)
#     102 for out in self._output_variables:
#     103     if getattr(self,'get_'+out+'_map'):
# --> 104         val = getattr(self,'get_'+out+'_map')(
#     105                 descriptor_ranges,resolution,*args,**kwargs)
#     106         setattr(self,out+'_map',val)
#     107         ismapped = True
#
# File G:\anaconda\Lib\site-packages\catmap\mappers\min_resid_mapper.py:673, in MinResidMapper.get_coverage_map(self, descriptor_ranges, resolution, initial_guess_adsorbate_names)
#     671     minresiditer +=1
#     672     norm_old = np.linalg.norm(isMapped)
# --> 673     isMapped = minresid_iteration(isMapped)
#     674     norm_new = np.linalg.norm(isMapped)
#     676 if n_unmapped == 0:
#
# File G:\anaconda\Lib\site-packages\catmap\mappers\min_resid_mapper.py:581, in MinResidMapper.get_coverage_map.<locals>.minresid_iteration(isMapped)
#     573         sol_numbers = self.retrieve_data(
#     574                 self._numbers_map,
#     575                 sol_pt,
#     576                 self.descriptor_decimal_precision)
#     577 else:
#     578     # Note that in case of the numbers solver
#     579     # the Bolzmann coverage is actually a
#     580     # "Boltzmann number" which include the slab
# --> 581     boltz_cvgs = self.get_initial_coverage(this_pt)
#     583     if self.max_initial_guesses is not None:
#     584         max_initial_guesses = min(len(boltz_cvgs),self.max_initial_guesses)
#
# File G:\anaconda\Lib\site-packages\catmap\mappers\min_resid_mapper.py:76, in MinResidMapper.get_initial_coverage(self, descriptors, *args, **kwargs)
#      60 def get_initial_coverage(self, descriptors, *args, **kwargs):
#      61     """
#      62         Return initial guess for coverages based on Boltzmann weights.
#      63         The return format is [descriptors, [coverages]] where the list
#    (...)
#      74
#      75     """
# ---> 76     params = self.scaler.get_rxn_parameters(descriptors)
#      77     solver_cvgs = self.solver.get_initial_coverage(params,*args,**kwargs)
#      78     return solver_cvgs
#
# File G:\anaconda\Lib\site-packages\catmap\scalers\generalized_linear_scaler.py:398, in GeneralizedLinearScaler.get_rxn_parameters(self, descriptors, *args, **kwargs)
#     396     return params
#     397 else:
# --> 398     params = self.get_formation_energy_parameters(descriptors)
#     399     return params
#
# File G:\anaconda\Lib\site-packages\catmap\scalers\generalized_linear_scaler.py:405, in GeneralizedLinearScaler.get_formation_energy_parameters(self, descriptors)
#     401 def get_formation_energy_parameters(self,descriptors):
#     402     """
#     403         :TODO:
#     404     """
# --> 405     free_energy_dict = self.get_free_energies(descriptors)
#     406     params = []
#     407     for ads in self.adsorbate_names + self.transition_state_names:
#
# File G:\anaconda\Lib\site-packages\catmap\scalers\scaler_base.py:138, in ScalerBase.get_free_energies(self, descriptors, **kwargs)
#     137 def get_free_energies(self,descriptors,**kwargs):
# --> 138     electronic_energy_dict = self.get_electronic_energies(descriptors)
#     139     self._electronic_energy_dict = electronic_energy_dict
#     140     thermodynamic_energy_dict = self.get_thermodynamic_energies(
#     141             descriptors=descriptors,**kwargs)
#
# File G:\anaconda\Lib\site-packages\catmap\scalers\generalized_linear_scaler.py:349, in GeneralizedLinearScaler.get_electronic_energies(self, descriptors)
#     347 full_descriptors = list(descriptors) + [1]
#     348 if self.coefficient_matrix is None:
# --> 349     self.coefficient_matrix = self.get_coefficient_matrix()
#     351 adsorption_energies = np.dot(self.coefficient_matrix,full_descriptors)
#     353 n_ads = len(self.adsorbate_names)
#
# File G:\anaconda\Lib\site-packages\catmap\scalers\generalized_linear_scaler.py:73, in GeneralizedLinearScaler.get_coefficient_matrix(self)
#      69 def get_coefficient_matrix(self):
#      70     """
#      71         :TODO:
#      72     """
# ---> 73     self.parameterize()
#      74     if not self.scaling_constraint_dict:
#      75         self.scaling_constraint_dict = {}
#
# File G:\anaconda\Lib\site-packages\catmap\scalers\generalized_linear_scaler.py:61, in GeneralizedLinearScaler.parameterize(self)
#      59             desc_list.append(desc_val)
#      60         except:
# ---> 61             raise ValueError(
#      62             'All surfaces must have numeric descriptor values: '+surf)
#      63     descriptor_dict[surf] = desc_list
#      64 self.descriptor_dict = descriptor_dict
#
# ValueError: All surfaces must have numeric descriptor values: CeO2

# %%
from ase.calculators.calculator import InputError
from glob import glob
import sys
from catmap.model import ReactionModel

model.output_variables += ['production_rate','rate','rate_control','coverage','selectivity_control','rxn_order']

output_variable = 'production_rate'
logfile = glob('*.log')
if len(logfile) > 1:
    raise InputError('Ambiguous logfile. Ensure that only one file ends with .log')
model = ReactionModel(setup_file=logfile[0])

if output_variable == 'rate_control':
    dim = 2
else:
    dim = 1

labels = model.output_labels['production_rate']

def flatten_2d(output):
    "Helper function for flattening rate_control output"
    flat = []
    for x in output:
        flat+= x
    return flat

#flatten rate_control labels
if output_variable == 'rate_control':
    flat_labels = []
    for i in labels[0]:
        for j in labels[1]:
            flat_labels.append('d'+i+'/d'+j)
    labels = flat_labels

#flatten elementary-step specific labels
if output_variable in ['rate','rate_constant','forward_rate_constant','reverse_rate_constant']:
    str_labels = []
    for label in labels:
        states = ['+'.join(s) for s in label]
        if len(states) == 2:
            new_label = '<->'.join(states)
        else:
            new_label = states[0]+'<->'+states[1]+'->'+states[2]
        str_labels.append(new_label)
    labels = str_labels

table = '\t'.join(list(['descriptor-'+d for d in model.descriptor_names])+list(labels))+'\n'

for pt, output in getattr(model,output_variable+'_map'):
    if dim == 2:
        output = flatten_2d(output)
    table += '\t'.join([str(float(i)) for i in pt+output])+'\n'

f = open(output_variable+'_table.txt','w')
f.write(table)
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       9 if len(logfile) > 1:
#      10     raise InputError('Ambiguous logfile. Ensure that only one file ends with .log')
# ---> 11 model = ReactionModel(setup_file=logfile[0])
#      13 if output_variable == 'rate_control':
#      14     dim = 2
#
# File D:\python\Lib\site-packages\catmap\model.py:140, in ReactionModel.__init__(self, **kwargs)
#     136 if hasattr(self,'setup_file'): #parse in setup file.
#     137     #Note that the syntax is simply python variable definitions.
#     138     #This is NOT idiot proof.
#     139     self.model_name = self.setup_file.rsplit('.',1)[0]
# --> 140     self.load(self.setup_file)
#
# File D:\python\Lib\site-packages\catmap\model.py:407, in ReactionModel.load(self, setup_file)
#     404 globs = {}
#     405 locs = defaults
# --> 407 exec(compile(open(setup_file, 'rb').read(), '<string>', 'exec'), globs, locs)
#     408 for var in locs.keys():
#     409     if var in self._classes:
#     410         #black magic to auto-import classes
#
# File <string>:226
#
# NameError: name 'np' is not defined

# %%
from catmap.model import ReactionModel

model = ReactionModel(setup_file='cracking.log')

#for MgO, cvgs in model.coverage_map:
   # print( 'descriptors:', MgO)
   #print( 'coverages', cvgs)
    
labels = model.output_labels['coverage']
for MgO ,cvg in model.coverage_map:
    print( 'descriptors',MgO)
    print( 'intermediates',labels)
    print( 'coverages', [float(c) for c in cvg])
# Out:
# '-f'
