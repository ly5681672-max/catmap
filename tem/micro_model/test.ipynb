# %%
import page

# -*- coding: utf-8 -*-
# page.encoding='utf-8'
 
from catmap import ReactionModel

mkm_file = 'MA.mkm'
model = ReactionModel(setup_file=mkm_file)
model.output_variables += ['production_rate','rate','rate_control','coverage','selectivity_control','rxn_order']
model.run()
    
from catmap import analyze
vm = analyze.VectorMap(model)
vm.plot_variable = 'rate' #tell the model which output to plot
vm.log_scale = True #rates should be plotted on a log-scale
vm.min = 1e-25 #minimum rate to plot
vm.max = 1e3 #maximum rate to plot
vm.plot(save='rate.pdf') #draw the plot and save it as "rate.pdf"

vm.unique_only = False
vm.plot(save='all_rates.pdf')
vm.unique_only = True

vm.production_rate_map = model.production_rate_map #attach map
vm.threshold = 1e-30 #do not plot rates below this
vm.plot_variable = 'production_rate'
vm.plot(save='production_rate.pdf')

vm.descriptor_labels = ['H reactivity [eV]', 'O reactivity [eV]']
vm.subplots_adjust_kwargs = {'left':0.2,'right':0.8,'bottom':0.15}
vm.plot(save='pretty_production_rate.pdf')

vm.plot_variable = 'coverage'
vm.log_scale = False
vm.min = 0
vm.max = 1
vm.plot(save='coverage.pdf')

vm.include_labels = ['O_s']
vm.plot(save='O_coverage.pdf')

sa = analyze.ScalingAnalysis(model)
sa.plot(save='scaling.pdf')
# Out:
# Input line {'surface_name': 'ZrO2-111', 'site_name': '111', 'species_name': 'CH3CHOCH-H', 'formation_energy': '1.129', 'bulk_structure': '[]', 'frequencies': '[]', 'other_parameters': 'Input File Tutorial.'} does not have all required fields.  Ignoring.
# If you find CatMAP useful to your research, please cite both the following papers:
#
#  Medford, A. J., Shi, C., Hoffmann, M. J., Lausche, A. C., Fitzgibbon, S. R., Bligaard, T., & Nørskov, J. K. (2015). CatMAP: a software package for descriptor-based microkinetic mapping of catalytic trends. Catalysis Letters, 145, 794-807.
#  Vijay, S., H. Heenen, H., Singh, A. R., Chan, K., & Voss, J. (2024). Number of sites-based solver for determining coverages from steady-state mean-field micro-kinetic models. Journal of Computational Chemistry, 45(9), 546-551.
#
# mapper_iteration_0: status - 100 points do not have valid solution.
# minresid_iteration_0: success - [ 2.00, 2.50] using coverages from [ 2.00, 2.50]
# minresid_iteration_0: success - [ 2.00, 1.80] using coverages from [ 2.00, 1.80]
# minresid_iteration_0: success - [ 2.00, 1.10] using coverages from [ 2.00, 1.10]
# minresid_iteration_0: success - [ 2.00, 0.40] using coverages from [ 2.00, 0.40]
# minresid_iteration_0: success - [ 2.00,-0.30] using coverages from [ 2.00,-0.30]
# minresid_iteration_0: success - [ 2.00,-1.00] using coverages from [ 2.00,-1.00]
# minresid_iteration_0: success - [ 2.00,-1.70] using coverages from [ 2.00,-1.70]
# minresid_iteration_0: success - [ 2.00,-2.40] using coverages from [ 2.00,-2.40]
# minresid_iteration_0: success - [ 2.00,-3.10] using coverages from [ 2.00,-3.10]
# minresid_iteration_0: success - [ 2.00,-3.80] using coverages from [ 2.00,-3.80]
# minresid_iteration_0: success - [ 1.61, 2.50] using coverages from [ 1.61, 2.50]
# minresid_iteration_0: success - [ 1.61, 1.80] using coverages from [ 1.61, 1.80]
# minresid_iteration_0: success - [ 1.61, 1.10] using coverages from [ 1.61, 1.10]
# minresid_iteration_0: success - [ 1.61, 0.40] using coverages from [ 1.61, 0.40]
# minresid_iteration_0: success - [ 1.61,-0.30] using coverages from [ 1.61,-0.30]
# minresid_iteration_0: success - [ 1.61,-1.00] using coverages from [ 1.61,-1.00]
# minresid_iteration_0: success - [ 1.61,-1.70] using coverages from [ 1.61,-1.70]
# minresid_iteration_0: success - [ 1.61,-2.40] using coverages from [ 1.61,-2.40]
# minresid_iteration_0: success - [ 1.61,-3.10] using coverages from [ 1.61,-3.10]
# minresid_iteration_0: success - [ 1.61,-3.80] using coverages from [ 1.61,-3.80]
# minresid_iteration_0: success - [ 1.22, 2.50] using coverages from [ 1.22, 2.50]
# minresid_iteration_0: success - [ 1.22, 1.80] using coverages from [ 1.22, 1.80]
# minresid_iteration_0: success - [ 1.22, 1.10] using coverages from [ 1.22, 1.10]
# minresid_iteration_0: success - [ 1.22, 0.40] using coverages from [ 1.22, 0.40]
# minresid_iteration_0: success - [ 1.22,-0.30] using coverages from [ 1.22,-0.30]
# minresid_iteration_0: success - [ 1.22,-1.00] using coverages from [ 1.22,-1.00]
# minresid_iteration_0: success - [ 1.22,-1.70] using coverages from [ 1.22,-1.70]
# minresid_iteration_0: success - [ 1.22,-2.40] using coverages from [ 1.22,-2.40]
# minresid_iteration_0: success - [ 1.22,-3.10] using coverages from [ 1.22,-3.10]
# minresid_iteration_0: success - [ 1.22,-3.80] using coverages from [ 1.22,-3.80]
# minresid_iteration_0: success - [ 0.83, 2.50] using coverages from [ 0.83, 2.50]
# minresid_iteration_0: success - [ 0.83, 1.80] using coverages from [ 0.83, 1.80]
# minresid_iteration_0: success - [ 0.83, 1.10] using coverages from [ 0.83, 1.10]
# minresid_iteration_0: success - [ 0.83, 0.40] using coverages from [ 0.83, 0.40]
# minresid_iteration_0: success - [ 0.83,-0.30] using coverages from [ 0.83,-0.30]
# minresid_iteration_0: success - [ 0.83,-1.00] using coverages from [ 0.83,-1.00]
# minresid_iteration_0: success - [ 0.83,-1.70] using coverages from [ 0.83,-1.70]
# minresid_iteration_0: success - [ 0.83,-2.40] using coverages from [ 0.83,-2.40]
# minresid_iteration_0: success - [ 0.83,-3.10] using coverages from [ 0.83,-3.10]
# minresid_iteration_0: success - [ 0.83,-3.80] using coverages from [ 0.83,-3.80]
# minresid_iteration_0: success - [ 0.44, 2.50] using coverages from [ 0.44, 2.50]
# minresid_iteration_0: success - [ 0.44, 1.80] using coverages from [ 0.44, 1.80]
# minresid_iteration_0: success - [ 0.44, 1.10] using coverages from [ 0.44, 1.10]
# minresid_iteration_0: success - [ 0.44, 0.40] using coverages from [ 0.44, 0.40]
# minresid_iteration_0: success - [ 0.44,-0.30] using coverages from [ 0.44,-0.30]
# minresid_iteration_0: success - [ 0.44,-1.00] using coverages from [ 0.44,-1.00]
# minresid_iteration_0: success - [ 0.44,-1.70] using coverages from [ 0.44,-1.70]
# minresid_iteration_0: success - [ 0.44,-2.40] using coverages from [ 0.44,-2.40]
# minresid_iteration_0: success - [ 0.44,-3.10] using coverages from [ 0.44,-3.10]
# minresid_iteration_0: success - [ 0.44,-3.80] using coverages from [ 0.44,-3.80]
# minresid_iteration_0: success - [ 0.06, 2.50] using coverages from [ 0.06, 2.50]
# minresid_iteration_0: success - [ 0.06, 1.80] using coverages from [ 0.06, 1.80]
# minresid_iteration_0: success - [ 0.06, 1.10] using coverages from [ 0.06, 1.10]
# minresid_iteration_0: success - [ 0.06, 0.40] using coverages from [ 0.06, 0.40]
# minresid_iteration_0: success - [ 0.06,-0.30] using coverages from [ 0.06,-0.30]
# minresid_iteration_0: success - [ 0.06,-1.00] using coverages from [ 0.06,-1.00]
# minresid_iteration_0: success - [ 0.06,-1.70] using coverages from [ 0.06,-1.70]
# minresid_iteration_0: success - [ 0.06,-2.40] using coverages from [ 0.06,-2.40]
# minresid_iteration_0: success - [ 0.06,-3.10] using coverages from [ 0.06,-3.10]
# minresid_iteration_0: success - [ 0.06,-3.80] using coverages from [ 0.06,-3.80]
# minresid_iteration_0: success - [-0.33, 2.50] using coverages from [-0.33, 2.50]
# minresid_iteration_0: success - [-0.33, 1.80] using coverages from [-0.33, 1.80]
# minresid_iteration_0: success - [-0.33, 1.10] using coverages from [-0.33, 1.10]
# minresid_iteration_0: success - [-0.33, 0.40] using coverages from [-0.33, 0.40]
# minresid_iteration_0: success - [-0.33,-0.30] using coverages from [-0.33,-0.30]
# minresid_iteration_0: success - [-0.33,-1.00] using coverages from [-0.33,-1.00]
# minresid_iteration_0: success - [-0.33,-1.70] using coverages from [-0.33,-1.70]
# minresid_iteration_0: success - [-0.33,-2.40] using coverages from [-0.33,-2.40]
# minresid_iteration_0: success - [-0.33,-3.10] using coverages from [-0.33,-3.10]
# minresid_iteration_0: success - [-0.33,-3.80] using coverages from [-0.33,-3.80]
# minresid_iteration_0: success - [-0.72, 2.50] using coverages from [-0.72, 2.50]
# minresid_iteration_0: success - [-0.72, 1.80] using coverages from [-0.72, 1.80]
# minresid_iteration_0: success - [-0.72, 1.10] using coverages from [-0.72, 1.10]
# minresid_iteration_0: success - [-0.72, 0.40] using coverages from [-0.72, 0.40]
# minresid_iteration_0: success - [-0.72,-0.30] using coverages from [-0.72,-0.30]
# minresid_iteration_0: success - [-0.72,-1.00] using coverages from [-0.72,-1.00]
# minresid_iteration_0: success - [-0.72,-1.70] using coverages from [-0.72,-1.70]
# minresid_iteration_0: success - [-0.72,-2.40] using coverages from [-0.72,-2.40]
# minresid_iteration_0: success - [-0.72,-3.10] using coverages from [-0.72,-3.10]
# minresid_iteration_0: success - [-0.72,-3.80] using coverages from [-0.72,-3.80]
# minresid_iteration_0: success - [-1.11, 2.50] using coverages from [-1.11, 2.50]
# minresid_iteration_0: success - [-1.11, 1.80] using coverages from [-1.11, 1.80]
# minresid_iteration_0: success - [-1.11, 1.10] using coverages from [-1.11, 1.10]
# minresid_iteration_0: success - [-1.11, 0.40] using coverages from [-1.11, 0.40]
# minresid_iteration_0: success - [-1.11,-0.30] using coverages from [-1.11,-0.30]
# minresid_iteration_0: success - [-1.11,-1.00] using coverages from [-1.11,-1.00]
# minresid_iteration_0: success - [-1.11,-1.70] using coverages from [-1.11,-1.70]
# minresid_iteration_0: success - [-1.11,-2.40] using coverages from [-1.11,-2.40]
# minresid_iteration_0: success - [-1.11,-3.10] using coverages from [-1.11,-3.10]
# minresid_iteration_0: success - [-1.11,-3.80] using coverages from [-1.11,-3.80]
# minresid_iteration_0: success - [-1.50, 2.50] using coverages from [-1.50, 2.50]
# minresid_iteration_0: success - [-1.50, 1.80] using coverages from [-1.50, 1.80]
# minresid_iteration_0: success - [-1.50, 1.10] using coverages from [-1.50, 1.10]
# minresid_iteration_0: success - [-1.50, 0.40] using coverages from [-1.50, 0.40]
# minresid_iteration_0: success - [-1.50,-0.30] using coverages from [-1.50,-0.30]
# minresid_iteration_0: success - [-1.50,-1.00] using coverages from [-1.50,-1.00]
# minresid_iteration_0: success - [-1.50,-1.70] using coverages from [-1.50,-1.70]
# minresid_iteration_0: success - [-1.50,-2.40] using coverages from [-1.50,-2.40]
# minresid_iteration_0: success - [-1.50,-3.10] using coverages from [-1.50,-3.10]
# minresid_iteration_0: success - [-1.50,-3.80] using coverages from [-1.50,-3.80]
# mapper_iteration_1: status - 0 points do not have valid solution.
# initial_evaluation: success - initial guess at point [ 2.00, 2.50]
# initial_evaluation: success - initial guess at point [ 2.00, 1.80]
# initial_evaluation: success - initial guess at point [ 2.00, 1.10]
# initial_evaluation: success - initial guess at point [ 2.00, 0.40]
# initial_evaluation: success - initial guess at point [ 2.00,-0.30]
# initial_evaluation: success - initial guess at point [ 2.00,-1.00]
# initial_evaluation: success - initial guess at point [ 2.00,-1.70]
# initial_evaluation: success - initial guess at point [ 2.00,-2.40]
# initial_evaluation: success - initial guess at point [ 2.00,-3.10]
# initial_evaluation: success - initial guess at point [ 2.00,-3.80]
# initial_evaluation: success - initial guess at point [ 1.61, 2.50]
# initial_evaluation: success - initial guess at point [ 1.61, 1.80]
# initial_evaluation: success - initial guess at point [ 1.61, 1.10]
# initial_evaluation: success - initial guess at point [ 1.61, 0.40]
# initial_evaluation: success - initial guess at point [ 1.61,-0.30]
# initial_evaluation: success - initial guess at point [ 1.61,-1.00]
# initial_evaluation: success - initial guess at point [ 1.61,-1.70]
# initial_evaluation: success - initial guess at point [ 1.61,-2.40]
# initial_evaluation: success - initial guess at point [ 1.61,-3.10]
# initial_evaluation: success - initial guess at point [ 1.61,-3.80]
# initial_evaluation: success - initial guess at point [ 1.22, 2.50]
# initial_evaluation: success - initial guess at point [ 1.22, 1.80]
# initial_evaluation: success - initial guess at point [ 1.22, 1.10]
# initial_evaluation: success - initial guess at point [ 1.22, 0.40]
# initial_evaluation: success - initial guess at point [ 1.22,-0.30]
# initial_evaluation: success - initial guess at point [ 1.22,-1.00]
# initial_evaluation: success - initial guess at point [ 1.22,-1.70]
# initial_evaluation: success - initial guess at point [ 1.22,-2.40]
# initial_evaluation: success - initial guess at point [ 1.22,-3.10]
# initial_evaluation: success - initial guess at point [ 1.22,-3.80]
# initial_evaluation: success - initial guess at point [ 0.83, 2.50]
# initial_evaluation: success - initial guess at point [ 0.83, 1.80]
# initial_evaluation: success - initial guess at point [ 0.83, 1.10]
# initial_evaluation: success - initial guess at point [ 0.83, 0.40]
# initial_evaluation: success - initial guess at point [ 0.83,-0.30]
# initial_evaluation: success - initial guess at point [ 0.83,-1.00]
# initial_evaluation: success - initial guess at point [ 0.83,-1.70]
# initial_evaluation: success - initial guess at point [ 0.83,-2.40]
# initial_evaluation: success - initial guess at point [ 0.83,-3.10]
# initial_evaluation: success - initial guess at point [ 0.83,-3.80]
# initial_evaluation: success - initial guess at point [ 0.44, 2.50]
# initial_evaluation: success - initial guess at point [ 0.44, 1.80]
# initial_evaluation: success - initial guess at point [ 0.44, 1.10]
# initial_evaluation: success - initial guess at point [ 0.44, 0.40]
# initial_evaluation: success - initial guess at point [ 0.44,-0.30]
# initial_evaluation: success - initial guess at point [ 0.44,-1.00]
# initial_evaluation: success - initial guess at point [ 0.44,-1.70]
# initial_evaluation: success - initial guess at point [ 0.44,-2.40]
# initial_evaluation: success - initial guess at point [ 0.44,-3.10]
# initial_evaluation: success - initial guess at point [ 0.44,-3.80]
# initial_evaluation: success - initial guess at point [ 0.06, 2.50]
# initial_evaluation: success - initial guess at point [ 0.06, 1.80]
# initial_evaluation: success - initial guess at point [ 0.06, 1.10]
# initial_evaluation: success - initial guess at point [ 0.06, 0.40]
# initial_evaluation: success - initial guess at point [ 0.06,-0.30]
# initial_evaluation: success - initial guess at point [ 0.06,-1.00]
# initial_evaluation: success - initial guess at point [ 0.06,-1.70]
# initial_evaluation: success - initial guess at point [ 0.06,-2.40]
# initial_evaluation: success - initial guess at point [ 0.06,-3.10]
# initial_evaluation: success - initial guess at point [ 0.06,-3.80]
# initial_evaluation: success - initial guess at point [-0.33, 2.50]
# initial_evaluation: success - initial guess at point [-0.33, 1.80]
# initial_evaluation: success - initial guess at point [-0.33, 1.10]
# initial_evaluation: success - initial guess at point [-0.33, 0.40]
# initial_evaluation: success - initial guess at point [-0.33,-0.30]
# initial_evaluation: success - initial guess at point [-0.33,-1.00]
# initial_evaluation: success - initial guess at point [-0.33,-1.70]
# initial_evaluation: success - initial guess at point [-0.33,-2.40]
# initial_evaluation: success - initial guess at point [-0.33,-3.10]
# initial_evaluation: success - initial guess at point [-0.33,-3.80]
# initial_evaluation: success - initial guess at point [-0.72, 2.50]
# initial_evaluation: success - initial guess at point [-0.72, 1.80]
# initial_evaluation: success - initial guess at point [-0.72, 1.10]
# initial_evaluation: success - initial guess at point [-0.72, 0.40]
# initial_evaluation: success - initial guess at point [-0.72,-0.30]
# initial_evaluation: success - initial guess at point [-0.72,-1.00]
# initial_evaluation: success - initial guess at point [-0.72,-1.70]
# initial_evaluation: success - initial guess at point [-0.72,-2.40]
# initial_evaluation: success - initial guess at point [-0.72,-3.10]
# initial_evaluation: success - initial guess at point [-0.72,-3.80]
# initial_evaluation: success - initial guess at point [-1.11, 2.50]
# initial_evaluation: success - initial guess at point [-1.11, 1.80]
# initial_evaluation: success - initial guess at point [-1.11, 1.10]
# initial_evaluation: success - initial guess at point [-1.11, 0.40]
# initial_evaluation: success - initial guess at point [-1.11,-0.30]
# initial_evaluation: success - initial guess at point [-1.11,-1.00]
# initial_evaluation: success - initial guess at point [-1.11,-1.70]
# initial_evaluation: success - initial guess at point [-1.11,-2.40]
# initial_evaluation: success - initial guess at point [-1.11,-3.10]
# initial_evaluation: success - initial guess at point [-1.11,-3.80]
# initial_evaluation: success - initial guess at point [-1.50, 2.50]
# initial_evaluation: success - initial guess at point [-1.50, 1.80]
# initial_evaluation: success - initial guess at point [-1.50, 1.10]
# initial_evaluation: success - initial guess at point [-1.50, 0.40]
# initial_evaluation: success - initial guess at point [-1.50,-0.30]
# initial_evaluation: success - initial guess at point [-1.50,-1.00]
# initial_evaluation: success - initial guess at point [-1.50,-1.70]
# initial_evaluation: success - initial guess at point [-1.50,-2.40]
# initial_evaluation: success - initial guess at point [-1.50,-3.10]
# initial_evaluation: success - initial guess at point [-1.50,-3.80]
# mapper_iteration_0: status - 0 points do not have valid solution.
# header_evaluation: fail - could not save transition_state_scaling_coefficients = [[np.float64(1.0743344946087319), np.float64(0.43706923471162956)], [np.float64(0.03656025132208084), np.float64(1.719673672023947)], [np.float64(0.6832306768194311), np.float64(1.7863032308386402)], [np.float64(-0.11037290001673755), np.float64(1.0073659135267161)]]
#
#
# header_evaluation: fail - could not save transition_state_scaling_coefficients = [[np.float64(1.0743344946087319), np.float64(0.43706923471162956)], [np.float64(0.03656025132208084), np.float64(1.719673672023947)], [np.float64(0.6832306768194311), np.float64(1.7863032308386402)], [np.float64(-0.11037290001673755), np.float64(1.0073659135267161)]]
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:330: UserWarning: The following kwargs were not used by contour: 'title'
#   plot = getattr(ax,self.plot_function)(*plot_in,**plot_args)
# D:\python\Lib\site-packages\catmap\analyze\analysis_base.py:838: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=(spy*plot_size,spx*plot_size))

# %%
from glob import glob
import sys
from catmap.model import ReactionModel
#import numpy as np

model.output_variables += ['production_rate', 'rate', 'rate_control', 'coverage', 'selectivity_control', 'rxn_order']

output_variable = 'production_rate'
logfile = glob('*.log')
print(len(logfile))
#if len(logfile) > 1:
#    raise InputError('Ambiguous logfile. Ensure that only one file ends with .log')
model = ReactionModel(setup_file=logfile[0])

if output_variable == 'rate_control':
    dim = 2
else:
    dim = 1

labels = model.output_labels['production_rate']


def flatten_2d(output):
    "Helper function for flattening rate_control output"
    flat = []
    for x in output:
        flat += x
    return flat


#flatten rate_control labels
if output_variable == 'rate_control':
    flat_labels = []
    for i in labels[0]:
        for j in labels[1]:
            flat_labels.append('d' + i + '/d' + j)
    labels = flat_labels

#flatten elementary-step specific labels
if output_variable in ['rate', 'rate_constant', 'forward_rate_constant', 'reverse_rate_constant']:
    str_labels = []
    for label in labels:
        states = ['+'.join(s) for s in label]
        if len(states) == 2:
            new_label = '<->'.join(states)
        else:
            new_label = states[0] + '<->' + states[1] + '->' + states[2]
        str_labels.append(new_label)
    labels = str_labels

table = '\t'.join(list(['descriptor-' + d for d in model.descriptor_names]) + list(labels)) + '\n'

for pt, output in getattr(model, output_variable + '_map'):
    if dim == 2:
        output = flatten_2d(output)
    table += '\t'.join([str(float(i)) for i in pt + output]) + '\n'

f = open(output_variable + '_table.txt', 'w')
f.write(table)
f.close()
# Out:
# 1

# %%
from catmap.model import ReactionModel

model = ReactionModel(setup_file='MA.log')

#for MgO, cvgs in model.coverage_map:
   # print( 'descriptors:', MgO)
   #print( 'coverages', cvgs)
    
labels = model.output_labels['coverage']
for MgO ,cvg in model.coverage_map:
    print( 'descriptors',MgO)
    print( 'intermediates',labels)
    print( 'coverages', [float(c) for c in cvg])
# Out:
# descriptors [np.float64(2.0), np.float64(2.5)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [2.8690858238998873e-27, 7.469325251231626e-19, 5.080216762068787e-43, 9.73905338901238e-19, 4.099040629917867e-14, 1.3548743594756899e-24, 2.7890772553713893e-18, 5.1353542837294284e-26, 0.999999999999959]
# descriptors [np.float64(2.0), np.float64(1.7999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.6595218548998836e-25, 7.469325251231625e-19, 1.2050579640658004e-41, 1.3820821052499081e-18, 4.099040629917867e-14, 4.199917516434459e-23, 1.134888181224112e-16, 8.964772696643436e-21, 0.9999999999999589]
# descriptors [np.float64(2.0), np.float64(1.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [2.9269487931884883e-22, 7.46932525123054e-19, 2.8584725984770397e-40, 1.9613312191170287e-18, 4.0990406299172715e-14, 4.1793107754322837e-23, 1.4385449418033403e-13, 1.5649777081043466e-15, 0.9999999999998136]
# descriptors [np.float64(2.0), np.float64(0.39999999999999947)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [2.680897715853382e-19, 7.469325247835661e-19, 6.791666484511228e-39, 2.7833513904296126e-18, 4.099040628054218e-14, 4.1791508099402026e-23, 1.8145724972661581e-10, 2.731977023954005e-10, 0.999999999545304]
# descriptors [np.float64(2.0), np.float64(-0.2999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.746948060956208e-16, 7.468967352677682e-19, 1.8091579696093037e-37, 3.949701961826764e-18, 4.0988442211841913e-14, 4.231530037326834e-23, 2.2602557701754268e-07, 4.7689755554880485e-05, 0.9999520842188266]
# descriptors [np.float64(2.0), np.float64(-1.0)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [9.873064577907582e-18, 1.0721723318256717e-42, 2.4956991606342913e-57, 3.666943003336409e-39, 7.98907986608195e-41, 1.847163614414305e-46, 1.773474181566646e-08, 0.9999999822652582, 3.275044465201148e-27]
# descriptors [np.float64(2.0), np.float64(-1.7000000000000002)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.0255188095048401e-19, 4.032293692351787e-43, 2.223295227007844e-56, 1.9542835851377434e-39, 2.834620406111111e-41, 5.66567568922104e-47, 1.2782255619431044e-10, 0.9999999998721775, 1.255996587521531e-27]
# descriptors [np.float64(2.0), np.float64(-2.4)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.0534276116012214e-21, 6.055126361110721e-43, 7.919292285535717e-55, 4.164623376554781e-39, 4.256629452843687e-41, 8.507288368208429e-47, 9.23608377818888e-13, 0.9999999999990764, 1.886077530354348e-27]
# descriptors [np.float64(2.0), np.float64(-3.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [6.075847181570737e-24, 1.6550794476832571e-43, 3.086892009579348e-54, 9.71203104427661e-40, 1.3220532539798606e-38, 2.6418698976121067e-44, 6.673723899818792e-15, 0.9999999999999933, 2.7131810462730817e-25]
# descriptors [np.float64(2.0), np.float64(-3.8)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.5479653526940556e-27, 6.185478817810355e-43, 1.9928987609702017e-52, 3.7512181022154035e-39, 5.3368690382951794e-39, 1.0664102671353265e-44, 4.822237625639041e-17, 1.0, 8.3041411547579e-26]
# descriptors [np.float64(1.6111111111111112), np.float64(2.5)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [8.203788572970531e-31, 1.7339045577142874e-18, 1.7367065251192328e-39, 2.020874645643421e-18, 5.2829932718836556e-14, 3.408815424242863e-16, 3.943653702251443e-23, 5.13535428377186e-26, 0.9999999999999468]
# descriptors [np.float64(1.6111111111111112), np.float64(1.7999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [3.6628358295330476e-24, 1.7339045577142877e-18, 4.119572308343241e-38, 2.8678502654561047e-18, 5.282993271883656e-14, 1.3689435440606952e-19, 1.238656787230431e-16, 8.964772777202783e-21, 0.999999999999947]
# descriptors [np.float64(1.6111111111111112), np.float64(1.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [2.6284647769398518e-20, 1.7339045577131998e-18, 9.771882462336486e-37, 4.0698047069875665e-18, 5.282993271880342e-14, 3.416961816074625e-20, 6.259370597253546e-13, 1.5649929578668237e-15, 0.9999999999993197]
# descriptors [np.float64(1.6111111111111112), np.float64(0.39999999999999947)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [2.3606618622913995e-17, 1.7339045558695329e-18, 2.398548688375859e-35, 5.775514340802798e-18, 5.282993266262916e-14, 3.41436451415641e-20, 7.901238760431223e-10, 2.7380723729524696e-10, 0.999999998936016]
# descriptors [np.float64(1.6111111111111112), np.float64(-0.2999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.1799685271781195e-14, 1.7338200750723648e-18, 1.9948665374369528e-33, 8.195710386684635e-18, 5.282735863696524e-14, 3.457113007876379e-20, 9.842001891997405e-07, 4.7739728399183456e-05, 0.999951276071317]
# descriptors [np.float64(1.6111111111111112), np.float64(-1.0)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [8.703628894654383e-16, 6.22234012748036e-43, 2.1308782750723944e-54, 1.9020993129950577e-39, 2.570406780805852e-41, 3.765863454769664e-44, 7.723622691264796e-08, 0.9999999227637723, 8.220514647989404e-28]
# descriptors [np.float64(1.6111111111111112), np.float64(-1.7000000000000002)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [5.670422410071207e-18, 1.7011839443086471e-43, 8.317233165567043e-54, 4.437344102184559e-40, 7.55460517551366e-39, 9.568644804780942e-42, 5.566772921464844e-10, 0.9999999994433227, 1.2026381527669161e-25]
# descriptors [np.float64(1.6111111111111112), np.float64(-2.4)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.647180760364377e-20, 2.5545986418189498e-43, 2.9625702160842442e-52, 9.45608216351099e-40, 1.1344499146963535e-38, 1.4371021648587068e-41, 4.021693606412907e-12, 0.9999999999959783, 1.8059654982214773e-25]
# descriptors [np.float64(1.6111111111111112), np.float64(-3.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.751801780708415e-22, 3.836185199084563e-43, 1.0552555433860102e-50, 2.015112339195131e-39, 1.703628392972157e-38, 2.158052094658642e-41, 2.9059581189800184e-14, 0.9999999999999709, 2.712097415623825e-25]
# descriptors [np.float64(1.6111111111111112), np.float64(-3.8)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [6.708537994209185e-24, 1.7051164503935074e-44, 4.214523510145893e-50, 4.814081569619815e-40, 9.946867715129987e-40, 1.260166545897247e-42, 2.0997603030112735e-16, 0.9999999999999998, 4.510419304046912e-26]
# descriptors [np.float64(1.2222222222222223), np.float64(2.5)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [7.212940214010562e-29, 4.025028920471495e-18, 5.9370489403342336e-36, 4.193358605068102e-18, 6.80891467799853e-14, 2.7892085860801236e-13, 1.7146044833552398e-22, 5.1353544059730543e-26, 0.9999999999996529]
# descriptors [np.float64(1.2222222222222223), np.float64(1.7999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.3067417510264864e-25, 4.0250289204715065e-18, 1.4083037090103868e-34, 5.9508513378712216e-18, 6.808914677998549e-14, 2.760506593892911e-13, 2.1851961466762855e-19, 8.965004340843327e-21, 0.9999999999996558]
# descriptors [np.float64(1.2222222222222223), np.float64(1.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [2.015858070190512e-18, 4.0250289204630656e-18, 3.340584239911549e-33, 8.444932804594793e-18, 6.80891467798427e-14, 3.208356671336358e-17, 2.3715421001987643e-12, 1.6088701489977731e-15, 0.9999999999975587]
# descriptors [np.float64(1.2222222222222223), np.float64(0.39999999999999947)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [3.735560436588591e-15, 4.02502887544119e-18, 9.099550941567933e-32, 1.1984317071188837e-17, 6.80891460182332e-14, 2.7898352941165656e-17, 3.440085423700506e-09, 7.747759909139656e-09, 0.9999999888120829]
# descriptors [np.float64(1.2222222222222223), np.float64(-0.2999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [3.5915189948762884e-12, 4.012681309992843e-18, 1.052054353587228e-28, 1.6954932175046092e-17, 6.788026921119277e-14, 2.877133726861536e-17, 4.181707648143578e-06, 0.00306352553271055, 0.9969322927559818]
# descriptors [np.float64(1.2222222222222223), np.float64(-1.0)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.4455745219180935e-14, 5.678233376550822e-44, 1.3867808692202888e-51, 7.750157124004477e-40, 3.2714244391568213e-40, 5.132676052590479e-40, 3.3605908136541616e-07, 0.9999996639408741, 3.902394256116527e-26]
# descriptors [np.float64(1.2222222222222223), np.float64(-1.7000000000000002)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [3.961752046588793e-16, 3.9578419500969955e-43, 2.8432366150818277e-50, 9.208436061251966e-40, 9.742965990895003e-39, 7.821367249162805e-39, 2.4239551430782387e-09, 0.9999999975760444, 1.2039637987585764e-25]
# descriptors [np.float64(1.2222222222222223), np.float64(-2.4)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [7.381512271921775e-18, 1.295016744479164e-44, 4.537104736041307e-49, 8.791245023981087e-40, 1.201103595472434e-39, 9.642314970081508e-40, 1.7514787833388775e-11, 0.9999999999824852, 6.332942331827927e-26]
# descriptors [np.float64(1.2222222222222223), np.float64(-3.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [7.578376777679046e-20, 1.9454712667043277e-44, 1.6163813971174866e-47, 1.873435217596355e-39, 1.8031954952302374e-39, 1.4482358209604554e-39, 1.2653489859732238e-13, 0.9999999999998734, 9.508234484166914e-26]
# descriptors [np.float64(1.2222222222222223), np.float64(-3.8)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [5.900011555830622e-22, 3.9604606957067385e-44, 1.4407438070023953e-46, 9.990347438447861e-40, 1.2801451283682572e-39, 1.0279763610371724e-39, 9.143041985797683e-16, 0.9999999999999991, 4.504039204179884e-26]
# descriptors [np.float64(0.8333333333333335), np.float64(2.5)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [6.351421337639957e-27, 9.34356953782152e-18, 2.029620410937913e-32, 8.701309813851811e-18, 8.775577914979001e-14, 2.2787557747727966e-10, 7.466032157298928e-22, 5.1357056695275255e-26, 0.9999999997720367]
# descriptors [np.float64(0.8333333333333335), np.float64(1.7999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.1388855093533815e-23, 9.343569537821638e-18, 4.814381658855187e-31, 1.2348145251496278e-17, 8.775577914979111e-14, 2.2786303502935708e-10, 9.417768856077203e-19, 9.63062076963663e-21, 0.9999999997720492]
# descriptors [np.float64(0.8333333333333335), np.float64(1.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [2.1907213369731155e-20, 9.343569537964928e-18, 1.1420013589808891e-29, 1.752341824579723e-17, 8.775577915113691e-14, 2.1239830109645824e-10, 1.2743981510545748e-15, 1.2773715014910114e-13, 0.9999999997873849]
# descriptors [np.float64(0.8333333333333335), np.float64(0.39999999999999947)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [3.568786586967493e-13, 9.343347242006173e-18, 3.153525173935501e-28, 2.4867125803259547e-17, 8.775369132473593e-14, 2.3252091652459418e-14, 1.4682763485097578e-08, 2.377685595702849e-05, 0.9999762084608116]
# descriptors [np.float64(0.8333333333333335), np.float64(-0.2999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.463164720431375e-09, 2.164188570993834e-18, 8.762036619131199e-27, 8.17401255178246e-18, 2.0326284739906432e-14, 5.435343008799045e-16, 4.251532447826879e-05, 0.7683341652701047, 0.23162331794223145]
# descriptors [np.float64(0.8333333333333335), np.float64(-1.0)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [2.8928863365030657e-12, 1.4914621018824634e-43, 4.896173158653735e-48, 1.6087555114449586e-39, 3.7736744820429355e-42, 1.6998741930951064e-37, 1.4629062295678696e-06, 0.9999985370908775, 1.8224689221472558e-26]
# descriptors [np.float64(0.8333333333333335), np.float64(-1.7000000000000002)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [6.329263359194723e-14, 1.9955715058766355e-44, 4.354355392710949e-47, 8.559525170713458e-40, 1.0304712744834058e-39, 5.2469878525165625e-37, 1.0554658628006519e-08, 0.9999999894452781, 4.21744102140879e-26]
# descriptors [np.float64(0.8333333333333335), np.float64(-2.4)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [6.503388920634722e-16, 2.994347679082116e-44, 1.5512737791518602e-45, 1.8240532357354626e-39, 1.5483143945053982e-39, 7.881065369187693e-37, 7.626475990543671e-11, 0.9999999999237346, 6.335680537641944e-26]
# descriptors [np.float64(0.8333333333333335), np.float64(-3.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [6.67719895407172e-18, 1.1255976146980494e-44, 1.381395911599061e-44, 9.717760666416494e-40, 5.806962388990558e-40, 2.955486573263379e-37, 5.510656639294979e-13, 0.9999999999994489, 2.3769200250464712e-26]
# descriptors [np.float64(0.8333333333333335), np.float64(-3.8)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [5.1927056621064323e-20, 9.1822839088068e-44, 4.925174026713044e-43, 2.0728536056648893e-39, 1.6464171011499748e-39, 8.381975914468237e-37, 3.981156646148298e-15, 0.999999999999996, 4.497378910028876e-26]
# descriptors [np.float64(0.4444444444444444), np.float64(2.5)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [5.5928472086687735e-25, 2.1689850487963117e-17, 6.938393617548418e-29, 1.8055402732339662e-17, 1.1310283221590215e-13, 1.861705448417746e-07, 3.2510166770260292e-21, 6.145394837317984e-26, 0.999999813829342]
# descriptors [np.float64(0.4444444444444444), np.float64(1.7999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.002809227977457e-21, 2.16898504879643e-17, 1.645828687680962e-27, 2.562266374635703e-17, 1.1310283221590834e-13, 1.8617049022679848e-07, 4.100658388110713e-18, 1.922905862639979e-18, 0.9999998138293966]
# descriptors [np.float64(0.4444444444444444), np.float64(1.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.798722753263626e-18, 2.1689850481594788e-17, 3.9040083024285807e-26, 3.636146515248501e-17, 1.1310283218269438e-13, 1.8610160856853157e-07, 5.174263873447401e-15, 3.6253798025465734e-10, 0.9999998135357351]
# descriptors [np.float64(0.4444444444444444), np.float64(0.39999999999999947)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.812237120378583e-15, 2.071572634165568e-17, 9.798779405974152e-25, 4.928356113638087e-17, 1.080232126422785e-13, 1.1375333747130988e-07, 9.741548658946038e-12, 0.044911579293126, 0.9550883069436821]
# descriptors [np.float64(0.4444444444444444), np.float64(-0.2999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.438972392394128e-07, 4.139584911215132e-18, 4.19989730601624e-24, 1.3975772002140365e-17, 2.15860768042229e-14, 2.724045839267041e-13, 0.00020500523097779117, 0.8089413385179646, 0.19085351235352443]
# descriptors [np.float64(0.4444444444444444), np.float64(-1.0)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [2.2102846998864368e-10, 3.447945931173238e-43, 1.6739780175003327e-44, 3.3389153094674895e-39, 7.902500899223478e-42, 6.607499483991735e-35, 6.3690517397086024e-06, 0.9999936307272318, 9.936693463921896e-27]
# descriptors [np.float64(0.4444444444444444), np.float64(-1.7000000000000002)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [5.5669213064558464e-12, 4.663616729573439e-44, 1.488806723044688e-43, 1.7763041015993695e-39, 1.3262139993859102e-39, 4.281173637979036e-34, 4.595529445192829e-08, 0.9999999540391387, 4.2117045595295867e-26]
# descriptors [np.float64(0.4444444444444444), np.float64(-2.4)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [5.718759323405793e-14, 7.003974803937827e-44, 5.303072485489541e-42, 3.7853455923137195e-39, 1.991344784682945e-39, 6.426321107047179e-34, 3.3204943219795134e-10, 0.9999999996678934, 6.324158154930218e-26]
# descriptors [np.float64(0.4444444444444444), np.float64(-3.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [5.8664232274619765e-16, 2.6419829518278315e-44, 4.722355910704268e-41, 2.016673830774356e-39, 7.448877699135914e-40, 2.4039236041700823e-34, 2.399188778820415e-12, 0.9999999999976003, 2.368306037219854e-26]
# descriptors [np.float64(0.4444444444444444), np.float64(-3.8)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.549418437676155e-18, 2.12785420260441e-43, 1.6836923903257536e-39, 4.301685606718e-39, 2.099437177630293e-39, 6.774173391102728e-34, 1.733618578992165e-14, 0.9999999999999827, 4.457964952023671e-26]
# descriptors [np.float64(0.05555555555555558), np.float64(2.5)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.9241255342081023e-23, 5.034245676934202e-17, 2.371576603569159e-25, 3.745966066730451e-17, 1.457489199594434e-13, 0.00015207514865794882, 1.4154113325070834e-20, 2.907997296180822e-23, 0.9998479248511962]
# descriptors [np.float64(0.05555555555555558), np.float64(1.7999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [8.829057724154154e-20, 5.034245676935371e-17, 5.625522310114937e-24, 5.3159505969478585e-17, 1.4574891995947724e-13, 0.0001520751484201745, 1.785323557602604e-17, 5.495108275436994e-15, 0.9998479248514285]
# descriptors [np.float64(0.05555555555555558), np.float64(1.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.5830688472860456e-16, 5.0342431818372404e-17, 1.334407657777632e-22, 7.543932924057076e-17, 1.4574884772283908e-13, 0.000152074924421525, 2.2519122197178275e-14, 4.957724406316847e-07, 0.9998474293029693]
# descriptors [np.float64(0.05555555555555558), np.float64(0.39999999999999947)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [2.4089016564792154e-13, 4.758737479005921e-17, 2.9922056403915408e-21, 1.011981268644823e-16, 1.3777254715766856e-13, 0.00016011541250579648, 2.412042780017253e-11, 0.054710442673981355, 0.9451294418890136]
# descriptors [np.float64(0.05555555555555558), np.float64(-0.2999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [5.075354318965923e-06, 7.908846980277209e-18, 1.1795571381112804e-20, 2.3867723375741553e-17, 2.2897291482934497e-14, 3.763641379840579e-10, 0.00035824714307875947, 0.8425596340832672, 0.157077043042948]
# descriptors [np.float64(0.05555555555555558), np.float64(-1.0)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.6989776947752292e-08, 1.840943354854004e-43, 1.430838036095742e-41, 1.7319038754211733e-39, 2.361239862028536e-41, 3.503402210565577e-33, 2.7707992487255426e-05, 0.9999722750177358, 8.715082167698687e-28]
# descriptors [np.float64(0.05555555555555558), np.float64(-1.7000000000000002)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.895412737469696e-10, 1.080807664943917e-43, 5.089476644274082e-40, 3.685575559247803e-39, 1.7066482588495757e-39, 3.5096230116095557e-31, 1.9982769323566742e-07, 0.9999997996827655, 4.208544510575068e-26]
# descriptors [np.float64(0.05555555555555558), np.float64(-2.4)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [5.021280241799348e-12, 4.074520550463672e-44, 4.532148409774799e-39, 1.9635198290566647e-39, 6.3867526547880464e-40, 1.3154480013585386e-31, 1.4430155774483362e-09, 0.9999999985519631, 1.5765196670039472e-26]
# descriptors [np.float64(0.05555555555555558), np.float64(-3.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [5.130904817920549e-14, 9.728819633702687e-46, 2.5224386248010118e-39, 6.538087852520905e-41, 1.4785892810491078e-41, 3.0539082322087774e-33, 1.0417853930469308e-11, 0.9999999999895308, 3.665209860195166e-28]
# descriptors [np.float64(0.05555555555555558), np.float64(-3.8)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [5.200430325191565e-16, 2.398465388671646e-47, 1.403946906368641e-39, 2.1771071493094857e-42, 3.337789094737321e-43, 6.921765799397774e-35, 7.518670415292271e-14, 0.9999999999999243, 8.375311193017988e-30]
# descriptors [np.float64(-0.33333333333333326), np.float64(2.5)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [3.8573571609701706e-21, 1.0396252734979356e-16, 7.212402513769415e-22, 6.914886776795387e-17, 1.671097485171808e-13, 0.11052743843412106, 5.482904925377384e-20, 7.403089106303161e-20, 0.8894725615657116]
# descriptors [np.float64(-0.33333333333333326), np.float64(1.7999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [6.916320217060786e-18, 1.0396252734943382e-16, 1.710825245507877e-20, 9.813008402631014e-17, 1.671097485166026e-13, 0.11052743843360978, 6.915840708452585e-17, 3.5888378629169268e-12, 0.889472561562634]
# descriptors [np.float64(-0.33333333333333326), np.float64(1.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.2401066287578587e-14, 1.0396241765738372e-16, 4.0581760760464397e-19, 1.3925756909232453e-16, 1.6710957219737104e-13, 0.11052753624853053, 8.723247731409869e-14, 8.406803071571209e-07, 0.8894716230708953]
# descriptors [np.float64(-0.33333333333333326), np.float64(0.39999999999999947)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.8218704032216873e-11, 9.67441414506387e-17, 8.957872821366827e-18, 1.8390105148122504e-16, 1.555068887278749e-13, 0.11681289601059874, 9.033785183590683e-11, 0.05547291075086871, 0.8277141931298202]
# descriptors [np.float64(-0.33333333333333326), np.float64(-0.2999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.781315374133599e-10, 1.091519800700899e-17, 2.3973835587274145e-17, 2.94447758435339e-17, 1.7545129395605137e-14, 0.2726859887054335, 6.262349250923225e-10, 0.633926812406344, 0.09338719808383843]
# descriptors [np.float64(-0.33333333333333326), np.float64(-1.0)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [6.329620725149256e-07, 2.1086668493067128e-44, 3.056127233176023e-39, 2.2456060201819052e-40, 9.516846231224173e-42, 2.4760798021667493e-31, 0.00010830697816238622, 0.9998910600597651, 1.8530578223539152e-30]
# descriptors [np.float64(-0.33333333333333326), np.float64(-1.7000000000000002)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.187618251855354e-08, 2.4869695825239928e-46, 1.6990847572822443e-39, 7.469235482417219e-42, 2.1314902841287895e-42, 3.038680027282265e-31, 8.468992062579676e-07, 0.9999991112246113, 4.086600772061096e-29]
# descriptors [np.float64(-0.33333333333333326), np.float64(-2.4)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.236364741350038e-10, 2.380631921762133e-47, 3.7826218232577714e-39, 9.948394671858941e-43, 1.970014982898437e-43, 2.911658246494229e-32, 6.049462262801385e-09, 0.9999999935269013, 3.79532084483378e-30]
# descriptors [np.float64(-0.33333333333333326), np.float64(-3.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.2224475863175904e-12, 5.936428605032117e-49, 2.1053709468697163e-39, 3.312742514491695e-44, 4.397614656371933e-45, 6.836929106301622e-34, 4.304483519713208e-11, 0.9999999999527327, 8.607742376937504e-32]
# descriptors [np.float64(-0.33333333333333326), np.float64(-3.8)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.07382472121007e-14, 6.494354574010877e-50, 4.68781922475864e-39, 4.4129487185049116e-45, 3.570282491097514e-46, 5.95216605036821e-35, 3.0504424296751815e-13, 0.9999999999996542, 7.329765030155589e-33]
# descriptors [np.float64(-0.7222222222222222), np.float64(2.5)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [3.7248743990692695e-21, 2.6465511682526684e-18, 2.7038574924455756e-20, 1.5735021884278396e-18, 2.3618878356077375e-15, 0.9902457876766823, 2.618181834287851e-21, 2.680045386140554e-19, 0.009754212323315367]
# descriptors [np.float64(-0.7222222222222222), np.float64(1.7999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [6.678775917535388e-18, 2.64655116823512e-18, 6.413712558997997e-19, 2.2329780219058846e-18, 2.3618878355920766e-15, 0.9902457876766941, 3.302433429131348e-18, 5.28310634992812e-14, 0.009754212323250692]
# descriptors [np.float64(-0.7222222222222222), np.float64(1.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.1975135178404543e-14, 2.646546042820988e-18, 1.5213682392520883e-17, 3.1688428694708397e-18, 2.361883261468062e-15, 0.9902457973470088, 4.165502610770562e-15, 9.220109623243925e-09, 0.009754193432863028]
# descriptors [np.float64(-0.7222222222222222), np.float64(0.39999999999999947)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.60673278421729e-11, 2.290158690829748e-18, 3.122814321633223e-16, 3.89138252987549e-18, 2.0438289719905636e-15, 0.9909130782578448, 3.958456016863269e-12, 0.0006462407360167046, 0.00844068098611034]
# descriptors [np.float64(-0.7222222222222222), np.float64(-0.2999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [3.912293994546107e-11, 8.465441250427842e-20, 2.7381414517464286e-16, 2.0412915860166114e-19, 7.554897465161997e-17, 0.9970077782315712, 6.9818233472405745e-12, 0.002680216753903556, 0.00031200496842012627]
# descriptors [np.float64(-0.7222222222222222), np.float64(-1.0)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.884701506553315e-32, 5.924736715626206e-48, 2.531506738583607e-39, 1.1290012977804271e-43, 1.2312554131764184e-44, 0.005353721095524617, 3.255847556075882e-33, 0.9946462789044754, 9.298294796809042e-33]
# descriptors [np.float64(-0.7222222222222222), np.float64(-1.7000000000000002)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [2.6731117618221836e-06, 1.4493096787031624e-49, 1.4180792750480916e-39, 3.783683619942142e-45, 6.543837666968471e-46, 1.6317241662397744e-31, 2.4463000993639534e-06, 0.9999948805881388, 9.813392032203854e-33]
# descriptors [np.float64(-0.7222222222222222), np.float64(-2.4)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [2.6322897083521555e-08, 1.4645349157419838e-50, 3.157217768025151e-39, 5.039852410745941e-46, 5.774387256701405e-47, 1.6866562688512515e-32, 1.5407060804552084e-08, 0.9999999582700421, 8.83213511440393e-34]
# descriptors [np.float64(-0.7222222222222222), np.float64(-3.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [2.3822206291105574e-10, 4.141525812037577e-52, 1.7575418597733094e-39, 1.67848680861371e-47, 1.1240978073434623e-48, 4.289620203769068e-34, 9.331624345537041e-11, 0.9999999996684616, 1.82989957198207e-35]
# descriptors [np.float64(-0.7222222222222222), np.float64(-3.8)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.946687901493711e-12, 5.525790186633484e-53, 3.914677487280039e-39, 2.2366972983750633e-48, 5.986214454160093e-50, 3.4424346171365227e-35, 5.676155837062329e-13, 0.9999999999974857, 1.2084888560400358e-36]
# descriptors [np.float64(-1.1111111111111112), np.float64(2.5)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.054266330614881e-22, 7.593860638424679e-21, 1.1425270785448009e-19, 4.0357893555112694e-21, 3.7626655284700786e-18, 0.9999879432372372, 1.4091841728423952e-23, 3.741030074211661e-22, 1.2056762762784427e-05]
# descriptors [np.float64(-1.1111111111111112), np.float64(1.7999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [7.269382382340535e-19, 7.593860638490948e-21, 2.710142932178991e-18, 5.727242706310386e-21, 3.762665528502913e-18, 0.999987943237237, 1.7774689524117888e-20, 6.530998253837323e-17, 1.205676276288964e-05]
# descriptors [np.float64(-1.1111111111111112), np.float64(1.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.3034100849475757e-15, 7.593845985097309e-21, 6.428609595134809e-17, 8.127591118523062e-21, 3.7626582679246985e-18, 0.9999879432491033, 2.2420063599152696e-17, 1.139753422086398e-11, 1.2056739497715419e-05]
# descriptors [np.float64(-1.1111111111111112), np.float64(0.39999999999999947)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.6862634068787418e-12, 6.450479481902622e-21, 1.2953077373364653e-15, 9.797362063098894e-21, 3.1961340804502325e-18, 0.9999888750619154, 2.0863428191447233e-14, 8.835184042165001e-07, 1.024141797203728e-05]
# descriptors [np.float64(-1.1111111111111112), np.float64(-0.2999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [2.6200254426280592e-12, 1.8988553092159858e-22, 9.04479085387449e-16, 4.092852843904048e-22, 9.408596965010331e-20, 0.9999964212103419, 2.533947877543383e-14, 3.2773059986820643e-06, 3.014810130729514e-07]
# descriptors [np.float64(-1.1111111111111112), np.float64(-1.0)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.898387185347523e-34, 2.6047458430420462e-51, 1.3968753375363037e-39, 3.781829045373315e-47, 6.486264951717799e-48, 0.8369093464472637, 1.5164926669090191e-35, 0.1630906535527363, 9.294042844099663e-36]
# descriptors [np.float64(-1.1111111111111112), np.float64(-1.7000000000000002)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.4533234320709615e-06, 3.6659646385023874e-52, 4.7341455999060526e-39, 7.668048026042614e-48, 7.493620282313997e-49, 1.0443759557512358e-29, 1.160684681674412e-06, 0.9999943859918863, 8.987634419416213e-36]
# descriptors [np.float64(-1.1111111111111112), np.float64(-2.4)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [7.92379558359775e-07, 1.074340435931827e-53, 2.6357936448205038e-39, 2.5541922533563378e-49, 1.3881523886458262e-50, 2.3321007193756378e-32, 3.3025876552657784e-10, 0.9999992072901829, 1.8038138294521906e-37]
# descriptors [np.float64(-1.1111111111111112), np.float64(-3.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [5.248283830631434e-09, 5.905714320810433e-54, 2.348560935930114e-38, 1.3615793403275113e-49, 2.4570214890999478e-51, 7.625430977119727e-33, 3.638843500665134e-12, 0.9999999947480773, 4.3238599188682394e-38]
# descriptors [np.float64(-1.1111111111111112), np.float64(-3.8)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [2.801767805813082e-11, 1.1770221803937747e-53, 8.371959156214086e-37, 2.903802976273311e-49, 1.874232057275601e-53, 4.55283079646533e-33, 3.649822106398361e-12, 0.9999999999683326, 1.57422314573948e-38]
# descriptors [np.float64(-1.5), np.float64(2.5)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.3713558006346074e-23, 2.1581086504573782e-23, 4.781647538903348e-19, 1.0252221601263716e-23, 5.93690794412071e-21, 0.9999999852396185, 7.513442181757437e-26, 4.580127858658532e-25, 1.4760381459113786e-08]
# descriptors [np.float64(-1.5), np.float64(1.7999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [7.837930360315508e-20, 2.1581086612559163e-23, 1.1342355546588028e-17, 1.4549065005690032e-23, 5.936907973827244e-21, 0.9999999852396184, 9.477051055766525e-23, 7.995515057364808e-20, 1.4760381532970376e-08]
# descriptors [np.float64(-1.5), np.float64(1.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.4053515454192102e-16, 2.1581045267542287e-23, 2.690469784507849e-16, 2.0646733379943885e-23, 5.9368965999068855e-21, 0.9999999852396324, 1.195397523726032e-19, 1.3954249019227273e-14, 1.4760353255051169e-08]
# descriptors [np.float64(-1.5), np.float64(0.39999999999999947)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.7545457656838363e-13, 1.8008185918300518e-23, 5.3253885871034035e-15, 2.4449272267840346e-23, 4.95401109739783e-21, 0.9999999865022801, 1.126800112889228e-16, 1.1808424976775207e-09, 1.2316696542800247e-08]
# descriptors [np.float64(-1.5), np.float64(-0.2999999999999998)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [2.2568140456442233e-13, 4.823290423271968e-25, 3.3833774028929295e-15, 9.29301164153875e-25, 1.326876254569289e-22, 0.999999995131887, 1.429975013003286e-16, 4.537994939463747e-09, 3.2988888914604107e-10]
# descriptors [np.float64(-1.5), np.float64(-1.0)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [7.988139537643882e-36, 6.138936435205195e-53, 7.05506559056382e-39, 1.1593071000522377e-49, 2.5747963465706e-52, 0.9998637776516827, 2.1817533051947672e-37, 0.00013622234831737987, 3.932815162827941e-39]
# descriptors [np.float64(-1.5), np.float64(-1.7000000000000002)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [1.6650143638860432e-32, 1.3246617927305655e-53, 2.4569836037876802e-37, 2.4154534483269988e-49, 8.527052454211323e-51, 0.01925508522103424, 4.908624020934606e-33, 0.9807449147789657, 1.003999105200231e-37]
# descriptors [np.float64(-1.5), np.float64(-2.4)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.886498313970724e-06, 1.0040588319549658e-53, 2.2542865505701688e-36, 1.3258808305300463e-49, 1.448008447020318e-51, 3.6911272170501633e-32, 4.629507125804148e-05, 0.9999488184304279, 2.3731667267851216e-38]
# descriptors [np.float64(-1.5), np.float64(-3.0999999999999996)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.3058207030544846e-08, 1.7342076858238385e-53, 8.035037138117649e-35, 2.8273671791202312e-49, 2.4092294373582686e-51, 3.526384445728196e-30, 3.015973782808656e-09, 0.9999999539258192, 4.4718940607917494e-39]
# descriptors [np.float64(-1.5), np.float64(-3.8)]
# intermediates ('C3H5O_s', 'C3H6O_s', 'C3H6_s', 'H2O_s', 'H2_s', 'H_s', 'OH_s', 'O_s')
# coverages [4.184059297913921e-10, 1.7511236074737414e-53, 2.849097795645142e-33, 5.997921516832205e-49, 4.634788284698771e-50, 1.4234247301973645e-29, 4.105236180010352e-11, 0.9999999995405418, 7.732173794452502e-38]
